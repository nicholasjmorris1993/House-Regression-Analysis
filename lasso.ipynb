# %%
# install missing packages
# %pip install plotly
# %pip install py-cpuinfo
# %pip install pandas-datareader
# %pip install nltk
# Out:
# Requirement already satisfied: plotly in /opt/conda/envs/sagemaker-distribution/lib/python3.8/site-packages (5.18.0)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/conda/envs/sagemaker-distribution/lib/python3.8/site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in /opt/conda/envs/sagemaker-distribution/lib/python3.8/site-packages (from plotly) (23.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: py-cpuinfo in /opt/conda/envs/sagemaker-distribution/lib/python3.8/site-packages (9.0.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas-datareader in /opt/conda/envs/sagemaker-distribution/lib/python3.8/site-packages (0.10.0)
# Requirement already satisfied: lxml in /opt/conda/envs/sagemaker-distribution/lib/python3.8/site-packages (from pandas-datareader) (4.9.3)
# Requirement already satisfied: pandas>=0.23 in /opt/conda/envs/sagemaker-distribution/lib/python3.8/site-packages (from pandas-datareader) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /opt/conda/envs/sagemaker-distribution/lib/python3.8/site-packages (from pandas-datareader) (2.31.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/sagemaker-distribution/lib/python3.8/site-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/sagemaker-distribution/lib/python3.8/site-packages (from pandas>=0.23->pandas-datareader) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/envs/sagemaker-distribution/lib/python3.8/site-packages (from pandas>=0.23->pandas-datareader) (2023.3)
# Requirement already satisfied: numpy>=1.20.3 in /opt/conda/envs/sagemaker-distribution/lib/python3.8/site-packages (from pandas>=0.23->pandas-datareader) (1.24.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/sagemaker-distribution/lib/python3.8/site-packages (from requests>=2.19.0->pandas-datareader) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/sagemaker-distribution/lib/python3.8/site-packages (from requests>=2.19.0->pandas-datareader) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/sagemaker-distribution/lib/python3.8/site-packages (from requests>=2.19.0->pandas-datareader) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/sagemaker-distribution/lib/python3.8/site-packages (from requests>=2.19.0->pandas-datareader) (2023.7.22)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/sagemaker-distribution/lib/python3.8/site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas-datareader) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: nltk in /opt/conda/envs/sagemaker-distribution/lib/python3.8/site-packages (3.8.1)
# Requirement already satisfied: click in /opt/conda/envs/sagemaker-distribution/lib/python3.8/site-packages (from nltk) (8.1.6)
# Requirement already satisfied: joblib in /opt/conda/envs/sagemaker-distribution/lib/python3.8/site-packages (from nltk) (1.3.0)
# Requirement already satisfied: regex>=2021.8.3 in /opt/conda/envs/sagemaker-distribution/lib/python3.8/site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in /opt/conda/envs/sagemaker-distribution/lib/python3.8/site-packages (from nltk) (4.65.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# check system details
import os
import psutil
import cpuinfo

ram_info = psutil.virtual_memory()
print(f"Total RAM: {ram_info.total / 1024 / 1024 / 1024:.2f} GB")
print(f"Available RAM: {ram_info.available / 1024 / 1024 / 1024:.2f} GB")
print(f"Used RAM: {ram_info.used / 1024 / 1024 / 1024:.2f} GB")
print(f"Percentage Usage Of RAM: {ram_info.percent}%")
print(f"CPU Cores: {os.cpu_count()}")
print(f"CPU Speed: {cpuinfo.get_cpu_info()['hz_actual_friendly']}")
disk_info = psutil.disk_usage(os.getcwd())
print(f"Total Disk: {disk_info.total / 1024 / 1024 / 1024:.2f} GB")
print(f"Available Disk: {disk_info.free / 1024 / 1024 / 1024:.2f} GB")
print(f"Used Disk: {disk_info.used / 1024 / 1024 / 1024:.2f} GB")
print(f"Percentage Usage Of Disk: {disk_info.percent}%")
# Out:
# Total RAM: 15.47 GB
# Available RAM: 13.69 GB
# Used RAM: 1.46 GB
# Percentage Usage Of RAM: 11.5%
# CPU Cores: 4
# CPU Speed: 2.5000 GHz
# Total Disk: 24.99 GB
# Available Disk: 12.35 GB
# Used Disk: 12.64 GB
# Percentage Usage Of Disk: 50.6%

# %%
# import requirements
import pandas as pd
from sklearn.metrics import mean_squared_error, r2_score
from lm_regressor import Regression
# Out:
# [nltk_data] Downloading package vader_lexicon to /home/studio-lab-
# [nltk_data]     user/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# get the data
prices = pd.read_csv("prices.csv")

# %%
# remove the id column
prices = prices.drop(columns="Id")

# %%
# replace missing values with None for string columns
for col in prices.columns:
    if prices[col].dtypes == "object" and prices[col].isna().any():
        prices[col] = prices[col].fillna("None")

# %%
# convert YrSold to a date
prices["DateSold"] = prices["YrSold"].astype(str) + "-01-01"
prices = prices.drop(columns="YrSold")

# %%
# fill in missing values for LotFrontage, MasVnrArea, and GarageYrBlt with 0
prices["LotFrontage"] = prices["LotFrontage"].fillna(0)
prices["MasVnrArea"] = prices["MasVnrArea"].fillna(0)
prices["GarageYrBlt"] = prices["GarageYrBlt"].fillna(0)

# %%
# shuffle the data
prices = prices.sample(frac=1, random_state=0).reset_index(drop=True)

# %%
# make sales price the first column
prices = pd.concat([prices[["SalePrice"]], prices.drop(columns="SalePrice")], axis="columns")

# %%
# get the testing data
y = prices[["SalePrice"]]
X = prices.drop(columns="SalePrice")
testX = X.tail(int(0.2 * X.shape[0])).reset_index(drop=True)
testy = y.tail(int(0.2 * y.shape[0])).reset_index(drop=True)

# %%
# build the model
print("\n---- House Regression Analysis ----\n")
model = Regression(
    name="Lasso Without Feature Engineering", 
    path=None,
    rename=False, 
    time=True, 
    text=False,
    binary=True, 
    imputation=False, 
    variance=True,
    scale=True,
    atwood=False,
    binning=False,
    reciprocal=False, 
    interaction=False, 
    selection=False,
    plots=True,
)
try:
    model.load()  # load the machine learning pipeline
    predictions = model.predict(testX)
except:
    model.explore(prices)
    model.validate(X, y)  # build the machine learning pipeline
    predictions = model.predict(testX)
    print("\nModel Performance:")
    print(f"R2: {model.r2}")
    print(f"RMSE: {model.rmse}")
    print(f"In Control: {model.in_control}")
# Out:
# ---- House Regression Analysis ----
#
# Visualizing The Data:
# > Plotting Correlations
# > SalePrice vs. GrLivArea
# > TotalBsmtSF vs. 1stFlrSF
# > Plotting SalePrice
# > Plotting LotFrontage
# > Plotting LotArea
# > Plotting YearBuilt
# > Plotting YearRemodAdd
# > Plotting MasVnrArea
# > Plotting BsmtFinSF1
# > Plotting BsmtFinSF2
# > Plotting BsmtUnfSF
# > Plotting TotalBsmtSF
# > Plotting 1stFlrSF
# > Plotting 2ndFlrSF
# > Plotting GrLivArea
# > Plotting GarageYrBlt
# > Plotting GarageArea
# > Plotting WoodDeckSF
# > Plotting OpenPorchSF
# > Plotting EnclosedPorch
# > Plotting ScreenPorch
# > Plotting MSZoning
# > Plotting Street
# > Plotting Alley
# > Plotting LotShape
# > Plotting LandContour
# > Plotting Utilities
# > Plotting LotConfig
# > Plotting LandSlope
# > Plotting Neighborhood
# > Plotting Condition1
# > Plotting Condition2
# > Plotting BldgType
# > Plotting HouseStyle
# > Plotting RoofStyle
# > Plotting RoofMatl
# > Plotting Exterior1st
# > Plotting Exterior2nd
# > Plotting MasVnrType
# > Plotting ExterQual
# > Plotting ExterCond
# > Plotting Foundation
# > Plotting BsmtQual
# > Plotting BsmtCond
# > Plotting BsmtExposure
# > Plotting BsmtFinType1
# > Plotting BsmtFinType2
# > Plotting Heating
# > Plotting HeatingQC
# > Plotting CentralAir
# > Plotting Electrical
# > Plotting KitchenQual
# > Plotting Functional
# > Plotting FireplaceQu
# > Plotting GarageType
# > Plotting GarageFinish
# > Plotting GarageQual
# > Plotting GarageCond
# > Plotting PavedDrive
# > Plotting PoolQC
# > Plotting Fence
# > Plotting MiscFeature
# > Plotting SaleType
# > Plotting SaleCondition
# > Plotting MSSubClass
# > Plotting OverallQual
# > Plotting OverallCond
# > Plotting LowQualFinSF
# > Plotting BsmtFullBath
# > Plotting BsmtHalfBath
# > Plotting FullBath
# > Plotting HalfBath
# > Plotting BedroomAbvGr
# > Plotting KitchenAbvGr
# > Plotting TotRmsAbvGrd
# > Plotting Fireplaces
# > Plotting GarageCars
# > Plotting 3SsnPorch
# > Plotting PoolArea
# > Plotting MiscVal
# > Plotting MoSold
# > MSZoning vs. Street
# > MSZoning vs. Alley
# > MSZoning vs. LotShape
# > MSZoning vs. LandContour
# > MSZoning vs. Utilities
# > MSZoning vs. LotConfig
# > MSZoning vs. LandSlope
# > MSZoning vs. Neighborhood
# > MSZoning vs. Condition1
# > MSZoning vs. Condition2
# > MSZoning vs. BldgType
# > MSZoning vs. HouseStyle
# > MSZoning vs. RoofStyle
# > MSZoning vs. RoofMatl
# > MSZoning vs. Exterior1st
# > MSZoning vs. Exterior2nd
# > MSZoning vs. MasVnrType
# > MSZoning vs. ExterQual
# > MSZoning vs. ExterCond
# > MSZoning vs. Foundation
# > MSZoning vs. BsmtQual
# > MSZoning vs. BsmtCond
# > MSZoning vs. BsmtExposure
# > MSZoning vs. BsmtFinType1
# > MSZoning vs. BsmtFinType2
# > MSZoning vs. Heating
# > MSZoning vs. HeatingQC
# > MSZoning vs. CentralAir
# > MSZoning vs. Electrical
# > MSZoning vs. KitchenQual
# > MSZoning vs. Functional
# > MSZoning vs. FireplaceQu
# > MSZoning vs. GarageType
# > MSZoning vs. GarageFinish
# > MSZoning vs. GarageQual
# > MSZoning vs. GarageCond
# > MSZoning vs. PavedDrive
# > MSZoning vs. PoolQC
# > MSZoning vs. Fence
# > MSZoning vs. MiscFeature
# > MSZoning vs. SaleType
# > MSZoning vs. SaleCondition
# > MSZoning vs. MSSubClass
# > MSZoning vs. OverallQual
# > MSZoning vs. OverallCond
# > MSZoning vs. LowQualFinSF
# > MSZoning vs. BsmtFullBath
# > MSZoning vs. BsmtHalfBath
# > MSZoning vs. FullBath
# > MSZoning vs. HalfBath
# > MSZoning vs. BedroomAbvGr
# > MSZoning vs. KitchenAbvGr
# > MSZoning vs. TotRmsAbvGrd
# > MSZoning vs. Fireplaces
# > MSZoning vs. GarageCars
# > MSZoning vs. 3SsnPorch
# > MSZoning vs. PoolArea
# > MSZoning vs. MiscVal
# > MSZoning vs. MoSold
# > Street vs. Alley
# > Street vs. LotShape
# > Street vs. LandContour
# > Street vs. Utilities
# > Street vs. LotConfig
# > Street vs. LandSlope
# > Street vs. Neighborhood
# > Street vs. Condition1
# > Street vs. Condition2
# > Street vs. BldgType
# > Street vs. HouseStyle
# > Street vs. RoofStyle
# > Street vs. RoofMatl
# > Street vs. Exterior1st
# > Street vs. Exterior2nd
# > Street vs. MasVnrType
# > Street vs. ExterQual
# > Street vs. ExterCond
# > Street vs. Foundation
# > Street vs. BsmtQual
# > Street vs. BsmtCond
# > Street vs. BsmtExposure
# > Street vs. BsmtFinType1
# > Street vs. BsmtFinType2
# > Street vs. Heating
# > Street vs. HeatingQC
# > Street vs. CentralAir
# > Street vs. Electrical
# > Street vs. KitchenQual
# > Street vs. Functional
# > Street vs. FireplaceQu
# > Street vs. GarageType
# > Street vs. GarageFinish
# > Street vs. GarageQual
# > Street vs. GarageCond
# > Street vs. PavedDrive
# > Street vs. PoolQC
# > Street vs. Fence
# > Street vs. MiscFeature
# > Street vs. SaleType
# > Street vs. SaleCondition
# > Street vs. MSSubClass
# > Street vs. OverallQual
# > Street vs. OverallCond
# > Street vs. LowQualFinSF
# > Street vs. BsmtFullBath
# > Street vs. BsmtHalfBath
# > Street vs. FullBath
# > Street vs. HalfBath
# > Street vs. BedroomAbvGr
# > Street vs. KitchenAbvGr
# > Street vs. TotRmsAbvGrd
# > Street vs. Fireplaces
# > Street vs. GarageCars
# > Street vs. 3SsnPorch
# > Street vs. PoolArea
# > Street vs. MiscVal
# > Street vs. MoSold
# > Alley vs. LotShape
# > Alley vs. LandContour
# > Alley vs. Utilities
# > Alley vs. LotConfig
# > Alley vs. LandSlope
# > Alley vs. Neighborhood
# > Alley vs. Condition1
# > Alley vs. Condition2
# > Alley vs. BldgType
# > Alley vs. HouseStyle
# > Alley vs. RoofStyle
# > Alley vs. RoofMatl
# > Alley vs. Exterior1st
# > Alley vs. Exterior2nd
# > Alley vs. MasVnrType
# > Alley vs. ExterQual
# > Alley vs. ExterCond
# > Alley vs. Foundation
# > Alley vs. BsmtQual
# > Alley vs. BsmtCond
# > Alley vs. BsmtExposure
# > Alley vs. BsmtFinType1
# > Alley vs. BsmtFinType2
# > Alley vs. Heating
# > Alley vs. HeatingQC
# > Alley vs. CentralAir
# > Alley vs. Electrical
# > Alley vs. KitchenQual
# > Alley vs. Functional
# > Alley vs. FireplaceQu
# > Alley vs. GarageType
# > Alley vs. GarageFinish
# > Alley vs. GarageQual
# > Alley vs. GarageCond
# > Alley vs. PavedDrive
# > Alley vs. PoolQC
# > Alley vs. Fence
# > Alley vs. MiscFeature
# > Alley vs. SaleType
# > Alley vs. SaleCondition
# > Alley vs. MSSubClass
# > Alley vs. OverallQual
# > Alley vs. OverallCond
# > Alley vs. LowQualFinSF
# > Alley vs. BsmtFullBath
# > Alley vs. BsmtHalfBath
# > Alley vs. FullBath
# > Alley vs. HalfBath
# > Alley vs. BedroomAbvGr
# > Alley vs. KitchenAbvGr
# > Alley vs. TotRmsAbvGrd
# > Alley vs. Fireplaces
# > Alley vs. GarageCars
# > Alley vs. 3SsnPorch
# > Alley vs. PoolArea
# > Alley vs. MiscVal
# > Alley vs. MoSold
# > LotShape vs. LandContour
# > LotShape vs. Utilities
# > LotShape vs. LotConfig
# > LotShape vs. LandSlope
# > LotShape vs. Neighborhood
# > LotShape vs. Condition1
# > LotShape vs. Condition2
# > LotShape vs. BldgType
# > LotShape vs. HouseStyle
# > LotShape vs. RoofStyle
# > LotShape vs. RoofMatl
# > LotShape vs. Exterior1st
# > LotShape vs. Exterior2nd
# > LotShape vs. MasVnrType
# > LotShape vs. ExterQual
# > LotShape vs. ExterCond
# > LotShape vs. Foundation
# > LotShape vs. BsmtQual
# > LotShape vs. BsmtCond
# > LotShape vs. BsmtExposure
# > LotShape vs. BsmtFinType1
# > LotShape vs. BsmtFinType2
# > LotShape vs. Heating
# > LotShape vs. HeatingQC
# > LotShape vs. CentralAir
# > LotShape vs. Electrical
# > LotShape vs. KitchenQual
# > LotShape vs. Functional
# > LotShape vs. FireplaceQu
# > LotShape vs. GarageType
# > LotShape vs. GarageFinish
# > LotShape vs. GarageQual
# > LotShape vs. GarageCond
# > LotShape vs. PavedDrive
# > LotShape vs. PoolQC
# > LotShape vs. Fence
# > LotShape vs. MiscFeature
# > LotShape vs. SaleType
# > LotShape vs. SaleCondition
# > LotShape vs. MSSubClass
# > LotShape vs. OverallQual
# > LotShape vs. OverallCond
# > LotShape vs. LowQualFinSF
# > LotShape vs. BsmtFullBath
# > LotShape vs. BsmtHalfBath
# > LotShape vs. FullBath
# > LotShape vs. HalfBath
# > LotShape vs. BedroomAbvGr
# > LotShape vs. KitchenAbvGr
# > LotShape vs. TotRmsAbvGrd
# > LotShape vs. Fireplaces
# > LotShape vs. GarageCars
# > LotShape vs. 3SsnPorch
# > LotShape vs. PoolArea
# > LotShape vs. MiscVal
# > LotShape vs. MoSold
# > LandContour vs. Utilities
# > LandContour vs. LotConfig
# > LandContour vs. LandSlope
# > LandContour vs. Neighborhood
# > LandContour vs. Condition1
# > LandContour vs. Condition2
# > LandContour vs. BldgType
# > LandContour vs. HouseStyle
# > LandContour vs. RoofStyle
# > LandContour vs. RoofMatl
# > LandContour vs. Exterior1st
# > LandContour vs. Exterior2nd
# > LandContour vs. MasVnrType
# > LandContour vs. ExterQual
# > LandContour vs. ExterCond
# > LandContour vs. Foundation
# > LandContour vs. BsmtQual
# > LandContour vs. BsmtCond
# > LandContour vs. BsmtExposure
# > LandContour vs. BsmtFinType1
# > LandContour vs. BsmtFinType2
# > LandContour vs. Heating
# > LandContour vs. HeatingQC
# > LandContour vs. CentralAir
# > LandContour vs. Electrical
# > LandContour vs. KitchenQual
# > LandContour vs. Functional
# > LandContour vs. FireplaceQu
# > LandContour vs. GarageType
# > LandContour vs. GarageFinish
# > LandContour vs. GarageQual
# > LandContour vs. GarageCond
# > LandContour vs. PavedDrive
# > LandContour vs. PoolQC
# > LandContour vs. Fence
# > LandContour vs. MiscFeature
# > LandContour vs. SaleType
# > LandContour vs. SaleCondition
# > LandContour vs. MSSubClass
# > LandContour vs. OverallQual
# > LandContour vs. OverallCond
# > LandContour vs. LowQualFinSF
# > LandContour vs. BsmtFullBath
# > LandContour vs. BsmtHalfBath
# > LandContour vs. FullBath
# > LandContour vs. HalfBath
# > LandContour vs. BedroomAbvGr
# > LandContour vs. KitchenAbvGr
# > LandContour vs. TotRmsAbvGrd
# > LandContour vs. Fireplaces
# > LandContour vs. GarageCars
# > LandContour vs. 3SsnPorch
# > LandContour vs. PoolArea
# > LandContour vs. MiscVal
# > LandContour vs. MoSold
# > Utilities vs. LotConfig
# > Utilities vs. LandSlope
# > Utilities vs. Neighborhood
# > Utilities vs. Condition1
# > Utilities vs. Condition2
# > Utilities vs. BldgType
# > Utilities vs. HouseStyle
# > Utilities vs. RoofStyle
# > Utilities vs. RoofMatl
# > Utilities vs. Exterior1st
# > Utilities vs. Exterior2nd
# > Utilities vs. MasVnrType
# > Utilities vs. ExterQual
# > Utilities vs. ExterCond
# > Utilities vs. Foundation
# > Utilities vs. BsmtQual
# > Utilities vs. BsmtCond
# > Utilities vs. BsmtExposure
# > Utilities vs. BsmtFinType1
# > Utilities vs. BsmtFinType2
# > Utilities vs. Heating
# > Utilities vs. HeatingQC
# > Utilities vs. CentralAir
# > Utilities vs. Electrical
# > Utilities vs. KitchenQual
# > Utilities vs. Functional
# > Utilities vs. FireplaceQu
# > Utilities vs. GarageType
# > Utilities vs. GarageFinish
# > Utilities vs. GarageQual
# > Utilities vs. GarageCond
# > Utilities vs. PavedDrive
# > Utilities vs. PoolQC
# > Utilities vs. Fence
# > Utilities vs. MiscFeature
# > Utilities vs. SaleType
# > Utilities vs. SaleCondition
# > Utilities vs. MSSubClass
# > Utilities vs. OverallQual
# > Utilities vs. OverallCond
# > Utilities vs. LowQualFinSF
# > Utilities vs. BsmtFullBath
# > Utilities vs. BsmtHalfBath
# > Utilities vs. FullBath
# > Utilities vs. HalfBath
# > Utilities vs. BedroomAbvGr
# > Utilities vs. KitchenAbvGr
# > Utilities vs. TotRmsAbvGrd
# > Utilities vs. Fireplaces
# > Utilities vs. GarageCars
# > Utilities vs. 3SsnPorch
# > Utilities vs. PoolArea
# > Utilities vs. MiscVal
# > Utilities vs. MoSold
# > LotConfig vs. LandSlope
# > LotConfig vs. Neighborhood
# > LotConfig vs. Condition1
# > LotConfig vs. Condition2
# > LotConfig vs. BldgType
# > LotConfig vs. HouseStyle
# > LotConfig vs. RoofStyle
# > LotConfig vs. RoofMatl
# > LotConfig vs. Exterior1st
# > LotConfig vs. Exterior2nd
# > LotConfig vs. MasVnrType
# > LotConfig vs. ExterQual
# > LotConfig vs. ExterCond
# > LotConfig vs. Foundation
# > LotConfig vs. BsmtQual
# > LotConfig vs. BsmtCond
# > LotConfig vs. BsmtExposure
# > LotConfig vs. BsmtFinType1
# > LotConfig vs. BsmtFinType2
# > LotConfig vs. Heating
# > LotConfig vs. HeatingQC
# > LotConfig vs. CentralAir
# > LotConfig vs. Electrical
# > LotConfig vs. KitchenQual
# > LotConfig vs. Functional
# > LotConfig vs. FireplaceQu
# > LotConfig vs. GarageType
# > LotConfig vs. GarageFinish
# > LotConfig vs. GarageQual
# > LotConfig vs. GarageCond
# > LotConfig vs. PavedDrive
# > LotConfig vs. PoolQC
# > LotConfig vs. Fence
# > LotConfig vs. MiscFeature
# > LotConfig vs. SaleType
# > LotConfig vs. SaleCondition
# > LotConfig vs. MSSubClass
# > LotConfig vs. OverallQual
# > LotConfig vs. OverallCond
# > LotConfig vs. LowQualFinSF
# > LotConfig vs. BsmtFullBath
# > LotConfig vs. BsmtHalfBath
# > LotConfig vs. FullBath
# > LotConfig vs. HalfBath
# > LotConfig vs. BedroomAbvGr
# > LotConfig vs. KitchenAbvGr
# > LotConfig vs. TotRmsAbvGrd
# > LotConfig vs. Fireplaces
# > LotConfig vs. GarageCars
# > LotConfig vs. 3SsnPorch
# > LotConfig vs. PoolArea
# > LotConfig vs. MiscVal
# > LotConfig vs. MoSold
# > LandSlope vs. Neighborhood
# > LandSlope vs. Condition1
# > LandSlope vs. Condition2
# > LandSlope vs. BldgType
# > LandSlope vs. HouseStyle
# > LandSlope vs. RoofStyle
# > LandSlope vs. RoofMatl
# > LandSlope vs. Exterior1st
# > LandSlope vs. Exterior2nd
# > LandSlope vs. MasVnrType
# > LandSlope vs. ExterQual
# > LandSlope vs. ExterCond
# > LandSlope vs. Foundation
# > LandSlope vs. BsmtQual
# > LandSlope vs. BsmtCond
# > LandSlope vs. BsmtExposure
# > LandSlope vs. BsmtFinType1
# > LandSlope vs. BsmtFinType2
# > LandSlope vs. Heating
# > LandSlope vs. HeatingQC
# > LandSlope vs. CentralAir
# > LandSlope vs. Electrical
# > LandSlope vs. KitchenQual
# > LandSlope vs. Functional
# > LandSlope vs. FireplaceQu
# > LandSlope vs. GarageType
# > LandSlope vs. GarageFinish
# > LandSlope vs. GarageQual
# > LandSlope vs. GarageCond
# > LandSlope vs. PavedDrive
# > LandSlope vs. PoolQC
# > LandSlope vs. Fence
# > LandSlope vs. MiscFeature
# > LandSlope vs. SaleType
# > LandSlope vs. SaleCondition
# > LandSlope vs. MSSubClass
# > LandSlope vs. OverallQual
# > LandSlope vs. OverallCond
# > LandSlope vs. LowQualFinSF
# > LandSlope vs. BsmtFullBath
# > LandSlope vs. BsmtHalfBath
# > LandSlope vs. FullBath
# > LandSlope vs. HalfBath
# > LandSlope vs. BedroomAbvGr
# > LandSlope vs. KitchenAbvGr
# > LandSlope vs. TotRmsAbvGrd
# > LandSlope vs. Fireplaces
# > LandSlope vs. GarageCars
# > LandSlope vs. 3SsnPorch
# > LandSlope vs. PoolArea
# > LandSlope vs. MiscVal
# > LandSlope vs. MoSold
# > Neighborhood vs. Condition1
# > Neighborhood vs. Condition2
# > Neighborhood vs. BldgType
# > Neighborhood vs. HouseStyle
# > Neighborhood vs. RoofStyle
# > Neighborhood vs. RoofMatl
# > Neighborhood vs. ExterQual
# > Neighborhood vs. ExterCond
# > Neighborhood vs. Foundation
# > Neighborhood vs. BsmtQual
# > Neighborhood vs. BsmtCond
# > Neighborhood vs. BsmtExposure
# > Neighborhood vs. BsmtFinType2
# > Neighborhood vs. Heating
# > Neighborhood vs. CentralAir
# > Neighborhood vs. Electrical
# > Neighborhood vs. KitchenQual
# > Neighborhood vs. Functional
# > Neighborhood vs. GarageType
# > Neighborhood vs. GarageQual
# > Neighborhood vs. GarageCond
# > Neighborhood vs. PavedDrive
# > Neighborhood vs. PoolQC
# > Neighborhood vs. Fence
# > Neighborhood vs. MiscFeature
# > Neighborhood vs. SaleType
# > Neighborhood vs. SaleCondition
# > Neighborhood vs. LowQualFinSF
# > Neighborhood vs. BsmtHalfBath
# > Neighborhood vs. FullBath
# > Neighborhood vs. HalfBath
# > Neighborhood vs. KitchenAbvGr
# > Neighborhood vs. 3SsnPorch
# > Neighborhood vs. PoolArea
# > Neighborhood vs. MiscVal
# > Condition1 vs. Condition2
# > Condition1 vs. BldgType
# > Condition1 vs. HouseStyle
# > Condition1 vs. RoofStyle
# > Condition1 vs. RoofMatl
# > Condition1 vs. Exterior1st
# > Condition1 vs. Exterior2nd
# > Condition1 vs. MasVnrType
# > Condition1 vs. ExterQual
# > Condition1 vs. ExterCond
# > Condition1 vs. Foundation
# > Condition1 vs. BsmtQual
# > Condition1 vs. BsmtCond
# > Condition1 vs. BsmtExposure
# > Condition1 vs. BsmtFinType1
# > Condition1 vs. BsmtFinType2
# > Condition1 vs. Heating
# > Condition1 vs. HeatingQC
# > Condition1 vs. CentralAir
# > Condition1 vs. Electrical
# > Condition1 vs. KitchenQual
# > Condition1 vs. Functional
# > Condition1 vs. FireplaceQu
# > Condition1 vs. GarageType
# > Condition1 vs. GarageFinish
# > Condition1 vs. GarageQual
# > Condition1 vs. GarageCond
# > Condition1 vs. PavedDrive
# > Condition1 vs. PoolQC
# > Condition1 vs. Fence
# > Condition1 vs. MiscFeature
# > Condition1 vs. SaleType
# > Condition1 vs. SaleCondition
# > Condition1 vs. MSSubClass
# > Condition1 vs. OverallQual
# > Condition1 vs. OverallCond
# > Condition1 vs. LowQualFinSF
# > Condition1 vs. BsmtFullBath
# > Condition1 vs. BsmtHalfBath
# > Condition1 vs. FullBath
# > Condition1 vs. HalfBath
# > Condition1 vs. BedroomAbvGr
# > Condition1 vs. KitchenAbvGr
# > Condition1 vs. TotRmsAbvGrd
# > Condition1 vs. Fireplaces
# > Condition1 vs. GarageCars
# > Condition1 vs. 3SsnPorch
# > Condition1 vs. PoolArea
# > Condition1 vs. MiscVal
# > Condition1 vs. MoSold
# > Condition2 vs. BldgType
# > Condition2 vs. HouseStyle
# > Condition2 vs. RoofStyle
# > Condition2 vs. RoofMatl
# > Condition2 vs. Exterior1st
# > Condition2 vs. Exterior2nd
# > Condition2 vs. MasVnrType
# > Condition2 vs. ExterQual
# > Condition2 vs. ExterCond
# > Condition2 vs. Foundation
# > Condition2 vs. BsmtQual
# > Condition2 vs. BsmtCond
# > Condition2 vs. BsmtExposure
# > Condition2 vs. BsmtFinType1
# > Condition2 vs. BsmtFinType2
# > Condition2 vs. Heating
# > Condition2 vs. HeatingQC
# > Condition2 vs. CentralAir
# > Condition2 vs. Electrical
# > Condition2 vs. KitchenQual
# > Condition2 vs. Functional
# > Condition2 vs. FireplaceQu
# > Condition2 vs. GarageType
# > Condition2 vs. GarageFinish
# > Condition2 vs. GarageQual
# > Condition2 vs. GarageCond
# > Condition2 vs. PavedDrive
# > Condition2 vs. PoolQC
# > Condition2 vs. Fence
# > Condition2 vs. MiscFeature
# > Condition2 vs. SaleType
# > Condition2 vs. SaleCondition
# > Condition2 vs. MSSubClass
# > Condition2 vs. OverallQual
# > Condition2 vs. OverallCond
# > Condition2 vs. LowQualFinSF
# > Condition2 vs. BsmtFullBath
# > Condition2 vs. BsmtHalfBath
# > Condition2 vs. FullBath
# > Condition2 vs. HalfBath
# > Condition2 vs. BedroomAbvGr
# > Condition2 vs. KitchenAbvGr
# > Condition2 vs. TotRmsAbvGrd
# > Condition2 vs. Fireplaces
# > Condition2 vs. GarageCars
# > Condition2 vs. 3SsnPorch
# > Condition2 vs. PoolArea
# > Condition2 vs. MiscVal
# > Condition2 vs. MoSold
# > BldgType vs. HouseStyle
# > BldgType vs. RoofStyle
# > BldgType vs. RoofMatl
# > BldgType vs. Exterior1st
# > BldgType vs. Exterior2nd
# > BldgType vs. MasVnrType
# > BldgType vs. ExterQual
# > BldgType vs. ExterCond
# > BldgType vs. Foundation
# > BldgType vs. BsmtQual
# > BldgType vs. BsmtCond
# > BldgType vs. BsmtExposure
# > BldgType vs. BsmtFinType1
# > BldgType vs. BsmtFinType2
# > BldgType vs. Heating
# > BldgType vs. HeatingQC
# > BldgType vs. CentralAir
# > BldgType vs. Electrical
# > BldgType vs. KitchenQual
# > BldgType vs. Functional
# > BldgType vs. FireplaceQu
# > BldgType vs. GarageType
# > BldgType vs. GarageFinish
# > BldgType vs. GarageQual
# > BldgType vs. GarageCond
# > BldgType vs. PavedDrive
# > BldgType vs. PoolQC
# > BldgType vs. Fence
# > BldgType vs. MiscFeature
# > BldgType vs. SaleType
# > BldgType vs. SaleCondition
# > BldgType vs. MSSubClass
# > BldgType vs. OverallQual
# > BldgType vs. OverallCond
# > BldgType vs. LowQualFinSF
# > BldgType vs. BsmtFullBath
# > BldgType vs. BsmtHalfBath
# > BldgType vs. FullBath
# > BldgType vs. HalfBath
# > BldgType vs. BedroomAbvGr
# > BldgType vs. KitchenAbvGr
# > BldgType vs. TotRmsAbvGrd
# > BldgType vs. Fireplaces
# > BldgType vs. GarageCars
# > BldgType vs. 3SsnPorch
# > BldgType vs. PoolArea
# > BldgType vs. MiscVal
# > BldgType vs. MoSold
# > HouseStyle vs. RoofStyle
# > HouseStyle vs. RoofMatl
# > HouseStyle vs. Exterior1st
# > HouseStyle vs. Exterior2nd
# > HouseStyle vs. MasVnrType
# > HouseStyle vs. ExterQual
# > HouseStyle vs. ExterCond
# > HouseStyle vs. Foundation
# > HouseStyle vs. BsmtQual
# > HouseStyle vs. BsmtCond
# > HouseStyle vs. BsmtExposure
# > HouseStyle vs. BsmtFinType1
# > HouseStyle vs. BsmtFinType2
# > HouseStyle vs. Heating
# > HouseStyle vs. HeatingQC
# > HouseStyle vs. CentralAir
# > HouseStyle vs. Electrical
# > HouseStyle vs. KitchenQual
# > HouseStyle vs. Functional
# > HouseStyle vs. FireplaceQu
# > HouseStyle vs. GarageType
# > HouseStyle vs. GarageFinish
# > HouseStyle vs. GarageQual
# > HouseStyle vs. GarageCond
# > HouseStyle vs. PavedDrive
# > HouseStyle vs. PoolQC
# > HouseStyle vs. Fence
# > HouseStyle vs. MiscFeature
# > HouseStyle vs. SaleType
# > HouseStyle vs. SaleCondition
# > HouseStyle vs. MSSubClass
# > HouseStyle vs. OverallQual
# > HouseStyle vs. OverallCond
# > HouseStyle vs. LowQualFinSF
# > HouseStyle vs. BsmtFullBath
# > HouseStyle vs. BsmtHalfBath
# > HouseStyle vs. FullBath
# > HouseStyle vs. HalfBath
# > HouseStyle vs. BedroomAbvGr
# > HouseStyle vs. KitchenAbvGr
# > HouseStyle vs. TotRmsAbvGrd
# > HouseStyle vs. Fireplaces
# > HouseStyle vs. GarageCars
# > HouseStyle vs. 3SsnPorch
# > HouseStyle vs. PoolArea
# > HouseStyle vs. MiscVal
# > RoofStyle vs. RoofMatl
# > RoofStyle vs. Exterior1st
# > RoofStyle vs. Exterior2nd
# > RoofStyle vs. MasVnrType
# > RoofStyle vs. ExterQual
# > RoofStyle vs. ExterCond
# > RoofStyle vs. Foundation
# > RoofStyle vs. BsmtQual
# > RoofStyle vs. BsmtCond
# > RoofStyle vs. BsmtExposure
# > RoofStyle vs. BsmtFinType1
# > RoofStyle vs. BsmtFinType2
# > RoofStyle vs. Heating
# > RoofStyle vs. HeatingQC
# > RoofStyle vs. CentralAir
# > RoofStyle vs. Electrical
# > RoofStyle vs. KitchenQual
# > RoofStyle vs. Functional
# > RoofStyle vs. FireplaceQu
# > RoofStyle vs. GarageType
# > RoofStyle vs. GarageFinish
# > RoofStyle vs. GarageQual
# > RoofStyle vs. GarageCond
# > RoofStyle vs. PavedDrive
# > RoofStyle vs. PoolQC
# > RoofStyle vs. Fence
# > RoofStyle vs. MiscFeature
# > RoofStyle vs. SaleType
# > RoofStyle vs. SaleCondition
# > RoofStyle vs. MSSubClass
# > RoofStyle vs. OverallQual
# > RoofStyle vs. OverallCond
# > RoofStyle vs. LowQualFinSF
# > RoofStyle vs. BsmtFullBath
# > RoofStyle vs. BsmtHalfBath
# > RoofStyle vs. FullBath
# > RoofStyle vs. HalfBath
# > RoofStyle vs. BedroomAbvGr
# > RoofStyle vs. KitchenAbvGr
# > RoofStyle vs. TotRmsAbvGrd
# > RoofStyle vs. Fireplaces
# > RoofStyle vs. GarageCars
# > RoofStyle vs. 3SsnPorch
# > RoofStyle vs. PoolArea
# > RoofStyle vs. MiscVal
# > RoofStyle vs. MoSold
# > RoofMatl vs. Exterior1st
# > RoofMatl vs. Exterior2nd
# > RoofMatl vs. MasVnrType
# > RoofMatl vs. ExterQual
# > RoofMatl vs. ExterCond
# > RoofMatl vs. Foundation
# > RoofMatl vs. BsmtQual
# > RoofMatl vs. BsmtCond
# > RoofMatl vs. BsmtExposure
# > RoofMatl vs. BsmtFinType1
# > RoofMatl vs. BsmtFinType2
# > RoofMatl vs. Heating
# > RoofMatl vs. HeatingQC
# > RoofMatl vs. CentralAir
# > RoofMatl vs. Electrical
# > RoofMatl vs. KitchenQual
# > RoofMatl vs. Functional
# > RoofMatl vs. FireplaceQu
# > RoofMatl vs. GarageType
# > RoofMatl vs. GarageFinish
# > RoofMatl vs. GarageQual
# > RoofMatl vs. GarageCond
# > RoofMatl vs. PavedDrive
# > RoofMatl vs. PoolQC
# > RoofMatl vs. Fence
# > RoofMatl vs. MiscFeature
# > RoofMatl vs. SaleType
# > RoofMatl vs. SaleCondition
# > RoofMatl vs. MSSubClass
# > RoofMatl vs. OverallQual
# > RoofMatl vs. OverallCond
# > RoofMatl vs. LowQualFinSF
# > RoofMatl vs. BsmtFullBath
# > RoofMatl vs. BsmtHalfBath
# > RoofMatl vs. FullBath
# > RoofMatl vs. HalfBath
# > RoofMatl vs. BedroomAbvGr
# > RoofMatl vs. KitchenAbvGr
# > RoofMatl vs. TotRmsAbvGrd
# > RoofMatl vs. Fireplaces
# > RoofMatl vs. GarageCars
# > RoofMatl vs. 3SsnPorch
# > RoofMatl vs. PoolArea
# > RoofMatl vs. MiscVal
# > RoofMatl vs. MoSold
# > Exterior1st vs. Exterior2nd
# > Exterior1st vs. MasVnrType
# > Exterior1st vs. ExterQual
# > Exterior1st vs. ExterCond
# > Exterior1st vs. Foundation
# > Exterior1st vs. BsmtQual
# > Exterior1st vs. BsmtCond
# > Exterior1st vs. BsmtExposure
# > Exterior1st vs. BsmtFinType1
# > Exterior1st vs. BsmtFinType2
# > Exterior1st vs. Heating
# > Exterior1st vs. HeatingQC
# > Exterior1st vs. CentralAir
# > Exterior1st vs. Electrical
# > Exterior1st vs. KitchenQual
# > Exterior1st vs. Functional
# > Exterior1st vs. FireplaceQu
# > Exterior1st vs. GarageType
# > Exterior1st vs. GarageFinish
# > Exterior1st vs. GarageQual
# > Exterior1st vs. GarageCond
# > Exterior1st vs. PavedDrive
# > Exterior1st vs. PoolQC
# > Exterior1st vs. Fence
# > Exterior1st vs. MiscFeature
# > Exterior1st vs. SaleType
# > Exterior1st vs. SaleCondition
# > Exterior1st vs. MSSubClass
# > Exterior1st vs. OverallQual
# > Exterior1st vs. OverallCond
# > Exterior1st vs. LowQualFinSF
# > Exterior1st vs. BsmtFullBath
# > Exterior1st vs. BsmtHalfBath
# > Exterior1st vs. FullBath
# > Exterior1st vs. HalfBath
# > Exterior1st vs. BedroomAbvGr
# > Exterior1st vs. KitchenAbvGr
# > Exterior1st vs. Fireplaces
# > Exterior1st vs. GarageCars
# > Exterior1st vs. 3SsnPorch
# > Exterior1st vs. PoolArea
# > Exterior1st vs. MiscVal
# > Exterior2nd vs. MasVnrType
# > Exterior2nd vs. ExterQual
# > Exterior2nd vs. ExterCond
# > Exterior2nd vs. Foundation
# > Exterior2nd vs. BsmtQual
# > Exterior2nd vs. BsmtCond
# > Exterior2nd vs. BsmtExposure
# > Exterior2nd vs. BsmtFinType1
# > Exterior2nd vs. BsmtFinType2
# > Exterior2nd vs. Heating
# > Exterior2nd vs. HeatingQC
# > Exterior2nd vs. CentralAir
# > Exterior2nd vs. Electrical
# > Exterior2nd vs. KitchenQual
# > Exterior2nd vs. Functional
# > Exterior2nd vs. FireplaceQu
# > Exterior2nd vs. GarageType
# > Exterior2nd vs. GarageFinish
# > Exterior2nd vs. GarageQual
# > Exterior2nd vs. GarageCond
# > Exterior2nd vs. PavedDrive
# > Exterior2nd vs. PoolQC
# > Exterior2nd vs. Fence
# > Exterior2nd vs. MiscFeature
# > Exterior2nd vs. SaleType
# > Exterior2nd vs. SaleCondition
# > Exterior2nd vs. MSSubClass
# > Exterior2nd vs. OverallQual
# > Exterior2nd vs. OverallCond
# > Exterior2nd vs. LowQualFinSF
# > Exterior2nd vs. BsmtFullBath
# > Exterior2nd vs. BsmtHalfBath
# > Exterior2nd vs. FullBath
# > Exterior2nd vs. HalfBath
# > Exterior2nd vs. BedroomAbvGr
# > Exterior2nd vs. KitchenAbvGr
# > Exterior2nd vs. Fireplaces
# > Exterior2nd vs. GarageCars
# > Exterior2nd vs. 3SsnPorch
# > Exterior2nd vs. PoolArea
# > Exterior2nd vs. MiscVal
# > MasVnrType vs. ExterQual
# > MasVnrType vs. ExterCond
# > MasVnrType vs. Foundation
# > MasVnrType vs. BsmtQual
# > MasVnrType vs. BsmtCond
# > MasVnrType vs. BsmtExposure
# > MasVnrType vs. BsmtFinType1
# > MasVnrType vs. BsmtFinType2
# > MasVnrType vs. Heating
# > MasVnrType vs. HeatingQC
# > MasVnrType vs. CentralAir
# > MasVnrType vs. Electrical
# > MasVnrType vs. KitchenQual
# > MasVnrType vs. Functional
# > MasVnrType vs. FireplaceQu
# > MasVnrType vs. GarageType
# > MasVnrType vs. GarageFinish
# > MasVnrType vs. GarageQual
# > MasVnrType vs. GarageCond
# > MasVnrType vs. PavedDrive
# > MasVnrType vs. PoolQC
# > MasVnrType vs. Fence
# > MasVnrType vs. MiscFeature
# > MasVnrType vs. SaleType
# > MasVnrType vs. SaleCondition
# > MasVnrType vs. MSSubClass
# > MasVnrType vs. OverallQual
# > MasVnrType vs. OverallCond
# > MasVnrType vs. LowQualFinSF
# > MasVnrType vs. BsmtFullBath
# > MasVnrType vs. BsmtHalfBath
# > MasVnrType vs. FullBath
# > MasVnrType vs. HalfBath
# > MasVnrType vs. BedroomAbvGr
# > MasVnrType vs. KitchenAbvGr
# > MasVnrType vs. TotRmsAbvGrd
# > MasVnrType vs. Fireplaces
# > MasVnrType vs. GarageCars
# > MasVnrType vs. 3SsnPorch
# > MasVnrType vs. PoolArea
# > MasVnrType vs. MiscVal
# > MasVnrType vs. MoSold
# > ExterQual vs. ExterCond
# > ExterQual vs. Foundation
# > ExterQual vs. BsmtQual
# > ExterQual vs. BsmtCond
# > ExterQual vs. BsmtExposure
# > ExterQual vs. BsmtFinType1
# > ExterQual vs. BsmtFinType2
# > ExterQual vs. Heating
# > ExterQual vs. HeatingQC
# > ExterQual vs. CentralAir
# > ExterQual vs. Electrical
# > ExterQual vs. KitchenQual
# > ExterQual vs. Functional
# > ExterQual vs. FireplaceQu
# > ExterQual vs. GarageType
# > ExterQual vs. GarageFinish
# > ExterQual vs. GarageQual
# > ExterQual vs. GarageCond
# > ExterQual vs. PavedDrive
# > ExterQual vs. PoolQC
# > ExterQual vs. Fence
# > ExterQual vs. MiscFeature
# > ExterQual vs. SaleType
# > ExterQual vs. SaleCondition
# > ExterQual vs. MSSubClass
# > ExterQual vs. OverallQual
# > ExterQual vs. OverallCond
# > ExterQual vs. LowQualFinSF
# > ExterQual vs. BsmtFullBath
# > ExterQual vs. BsmtHalfBath
# > ExterQual vs. FullBath
# > ExterQual vs. HalfBath
# > ExterQual vs. BedroomAbvGr
# > ExterQual vs. KitchenAbvGr
# > ExterQual vs. TotRmsAbvGrd
# > ExterQual vs. Fireplaces
# > ExterQual vs. GarageCars
# > ExterQual vs. 3SsnPorch
# > ExterQual vs. PoolArea
# > ExterQual vs. MiscVal
# > ExterQual vs. MoSold
# > ExterCond vs. Foundation
# > ExterCond vs. BsmtQual
# > ExterCond vs. BsmtCond
# > ExterCond vs. BsmtExposure
# > ExterCond vs. BsmtFinType1
# > ExterCond vs. BsmtFinType2
# > ExterCond vs. Heating
# > ExterCond vs. HeatingQC
# > ExterCond vs. CentralAir
# > ExterCond vs. Electrical
# > ExterCond vs. KitchenQual
# > ExterCond vs. Functional
# > ExterCond vs. FireplaceQu
# > ExterCond vs. GarageType
# > ExterCond vs. GarageFinish
# > ExterCond vs. GarageQual
# > ExterCond vs. GarageCond
# > ExterCond vs. PavedDrive
# > ExterCond vs. PoolQC
# > ExterCond vs. Fence
# > ExterCond vs. MiscFeature
# > ExterCond vs. SaleType
# > ExterCond vs. SaleCondition
# > ExterCond vs. MSSubClass
# > ExterCond vs. OverallQual
# > ExterCond vs. OverallCond
# > ExterCond vs. LowQualFinSF
# > ExterCond vs. BsmtFullBath
# > ExterCond vs. BsmtHalfBath
# > ExterCond vs. FullBath
# > ExterCond vs. HalfBath
# > ExterCond vs. BedroomAbvGr
# > ExterCond vs. KitchenAbvGr
# > ExterCond vs. TotRmsAbvGrd
# > ExterCond vs. Fireplaces
# > ExterCond vs. GarageCars
# > ExterCond vs. 3SsnPorch
# > ExterCond vs. PoolArea
# > ExterCond vs. MiscVal
# > ExterCond vs. MoSold
# > Foundation vs. BsmtQual
# > Foundation vs. BsmtCond
# > Foundation vs. BsmtExposure
# > Foundation vs. BsmtFinType1
# > Foundation vs. BsmtFinType2
# > Foundation vs. Heating
# > Foundation vs. HeatingQC
# > Foundation vs. CentralAir
# > Foundation vs. Electrical
# > Foundation vs. KitchenQual
# > Foundation vs. Functional
# > Foundation vs. FireplaceQu
# > Foundation vs. GarageType
# > Foundation vs. GarageFinish
# > Foundation vs. GarageQual
# > Foundation vs. GarageCond
# > Foundation vs. PavedDrive
# > Foundation vs. PoolQC
# > Foundation vs. Fence
# > Foundation vs. MiscFeature
# > Foundation vs. SaleType
# > Foundation vs. SaleCondition
# > Foundation vs. MSSubClass
# > Foundation vs. OverallQual
# > Foundation vs. OverallCond
# > Foundation vs. LowQualFinSF
# > Foundation vs. BsmtFullBath
# > Foundation vs. BsmtHalfBath
# > Foundation vs. FullBath
# > Foundation vs. HalfBath
# > Foundation vs. BedroomAbvGr
# > Foundation vs. KitchenAbvGr
# > Foundation vs. TotRmsAbvGrd
# > Foundation vs. Fireplaces
# > Foundation vs. GarageCars
# > Foundation vs. 3SsnPorch
# > Foundation vs. PoolArea
# > Foundation vs. MiscVal
# > BsmtQual vs. BsmtCond
# > BsmtQual vs. BsmtExposure
# > BsmtQual vs. BsmtFinType1
# > BsmtQual vs. BsmtFinType2
# > BsmtQual vs. Heating
# > BsmtQual vs. HeatingQC
# > BsmtQual vs. CentralAir
# > BsmtQual vs. Electrical
# > BsmtQual vs. KitchenQual
# > BsmtQual vs. Functional
# > BsmtQual vs. FireplaceQu
# > BsmtQual vs. GarageType
# > BsmtQual vs. GarageFinish
# > BsmtQual vs. GarageQual
# > BsmtQual vs. GarageCond
# > BsmtQual vs. PavedDrive
# > BsmtQual vs. PoolQC
# > BsmtQual vs. Fence
# > BsmtQual vs. MiscFeature
# > BsmtQual vs. SaleType
# > BsmtQual vs. SaleCondition
# > BsmtQual vs. MSSubClass
# > BsmtQual vs. OverallQual
# > BsmtQual vs. OverallCond
# > BsmtQual vs. LowQualFinSF
# > BsmtQual vs. BsmtFullBath
# > BsmtQual vs. BsmtHalfBath
# > BsmtQual vs. FullBath
# > BsmtQual vs. HalfBath
# > BsmtQual vs. BedroomAbvGr
# > BsmtQual vs. KitchenAbvGr
# > BsmtQual vs. TotRmsAbvGrd
# > BsmtQual vs. Fireplaces
# > BsmtQual vs. GarageCars
# > BsmtQual vs. 3SsnPorch
# > BsmtQual vs. PoolArea
# > BsmtQual vs. MiscVal
# > BsmtCond vs. BsmtExposure
# > BsmtCond vs. BsmtFinType1
# > BsmtCond vs. BsmtFinType2
# > BsmtCond vs. Heating
# > BsmtCond vs. HeatingQC
# > BsmtCond vs. CentralAir
# > BsmtCond vs. Electrical
# > BsmtCond vs. KitchenQual
# > BsmtCond vs. Functional
# > BsmtCond vs. FireplaceQu
# > BsmtCond vs. GarageType
# > BsmtCond vs. GarageFinish
# > BsmtCond vs. GarageQual
# > BsmtCond vs. GarageCond
# > BsmtCond vs. PavedDrive
# > BsmtCond vs. PoolQC
# > BsmtCond vs. Fence
# > BsmtCond vs. MiscFeature
# > BsmtCond vs. SaleType
# > BsmtCond vs. SaleCondition
# > BsmtCond vs. MSSubClass
# > BsmtCond vs. OverallQual
# > BsmtCond vs. OverallCond
# > BsmtCond vs. LowQualFinSF
# > BsmtCond vs. BsmtFullBath
# > BsmtCond vs. BsmtHalfBath
# > BsmtCond vs. FullBath
# > BsmtCond vs. HalfBath
# > BsmtCond vs. BedroomAbvGr
# > BsmtCond vs. KitchenAbvGr
# > BsmtCond vs. TotRmsAbvGrd
# > BsmtCond vs. Fireplaces
# > BsmtCond vs. GarageCars
# > BsmtCond vs. 3SsnPorch
# > BsmtCond vs. PoolArea
# > BsmtCond vs. MiscVal
# > BsmtCond vs. MoSold
# > BsmtExposure vs. BsmtFinType1
# > BsmtExposure vs. BsmtFinType2
# > BsmtExposure vs. Heating
# > BsmtExposure vs. HeatingQC
# > BsmtExposure vs. CentralAir
# > BsmtExposure vs. Electrical
# > BsmtExposure vs. KitchenQual
# > BsmtExposure vs. Functional
# > BsmtExposure vs. FireplaceQu
# > BsmtExposure vs. GarageType
# > BsmtExposure vs. GarageFinish
# > BsmtExposure vs. GarageQual
# > BsmtExposure vs. GarageCond
# > BsmtExposure vs. PavedDrive
# > BsmtExposure vs. PoolQC
# > BsmtExposure vs. Fence
# > BsmtExposure vs. MiscFeature
# > BsmtExposure vs. SaleType
# > BsmtExposure vs. SaleCondition
# > BsmtExposure vs. MSSubClass
# > BsmtExposure vs. OverallQual
# > BsmtExposure vs. OverallCond
# > BsmtExposure vs. LowQualFinSF
# > BsmtExposure vs. BsmtFullBath
# > BsmtExposure vs. BsmtHalfBath
# > BsmtExposure vs. FullBath
# > BsmtExposure vs. HalfBath
# > BsmtExposure vs. BedroomAbvGr
# > BsmtExposure vs. KitchenAbvGr
# > BsmtExposure vs. TotRmsAbvGrd
# > BsmtExposure vs. Fireplaces
# > BsmtExposure vs. GarageCars
# > BsmtExposure vs. 3SsnPorch
# > BsmtExposure vs. PoolArea
# > BsmtExposure vs. MiscVal
# > BsmtExposure vs. MoSold
# > BsmtFinType1 vs. BsmtFinType2
# > BsmtFinType1 vs. Heating
# > BsmtFinType1 vs. HeatingQC
# > BsmtFinType1 vs. CentralAir
# > BsmtFinType1 vs. Electrical
# > BsmtFinType1 vs. KitchenQual
# > BsmtFinType1 vs. Functional
# > BsmtFinType1 vs. FireplaceQu
# > BsmtFinType1 vs. GarageType
# > BsmtFinType1 vs. GarageFinish
# > BsmtFinType1 vs. GarageQual
# > BsmtFinType1 vs. GarageCond
# > BsmtFinType1 vs. PavedDrive
# > BsmtFinType1 vs. PoolQC
# > BsmtFinType1 vs. Fence
# > BsmtFinType1 vs. MiscFeature
# > BsmtFinType1 vs. SaleType
# > BsmtFinType1 vs. SaleCondition
# > BsmtFinType1 vs. MSSubClass
# > BsmtFinType1 vs. OverallCond
# > BsmtFinType1 vs. LowQualFinSF
# > BsmtFinType1 vs. BsmtFullBath
# > BsmtFinType1 vs. BsmtHalfBath
# > BsmtFinType1 vs. FullBath
# > BsmtFinType1 vs. HalfBath
# > BsmtFinType1 vs. BedroomAbvGr
# > BsmtFinType1 vs. KitchenAbvGr
# > BsmtFinType1 vs. Fireplaces
# > BsmtFinType1 vs. GarageCars
# > BsmtFinType1 vs. 3SsnPorch
# > BsmtFinType1 vs. PoolArea
# > BsmtFinType1 vs. MiscVal
# > BsmtFinType2 vs. Heating
# > BsmtFinType2 vs. HeatingQC
# > BsmtFinType2 vs. CentralAir
# > BsmtFinType2 vs. Electrical
# > BsmtFinType2 vs. KitchenQual
# > BsmtFinType2 vs. Functional
# > BsmtFinType2 vs. FireplaceQu
# > BsmtFinType2 vs. GarageType
# > BsmtFinType2 vs. GarageFinish
# > BsmtFinType2 vs. GarageQual
# > BsmtFinType2 vs. GarageCond
# > BsmtFinType2 vs. PavedDrive
# > BsmtFinType2 vs. PoolQC
# > BsmtFinType2 vs. Fence
# > BsmtFinType2 vs. MiscFeature
# > BsmtFinType2 vs. SaleType
# > BsmtFinType2 vs. SaleCondition
# > BsmtFinType2 vs. MSSubClass
# > BsmtFinType2 vs. OverallQual
# > BsmtFinType2 vs. OverallCond
# > BsmtFinType2 vs. LowQualFinSF
# > BsmtFinType2 vs. BsmtFullBath
# > BsmtFinType2 vs. BsmtHalfBath
# > BsmtFinType2 vs. FullBath
# > BsmtFinType2 vs. HalfBath
# > BsmtFinType2 vs. BedroomAbvGr
# > BsmtFinType2 vs. KitchenAbvGr
# > BsmtFinType2 vs. TotRmsAbvGrd
# > BsmtFinType2 vs. Fireplaces
# > BsmtFinType2 vs. GarageCars
# > BsmtFinType2 vs. 3SsnPorch
# > BsmtFinType2 vs. PoolArea
# > BsmtFinType2 vs. MiscVal
# > BsmtFinType2 vs. MoSold
# > Heating vs. HeatingQC
# > Heating vs. CentralAir
# > Heating vs. Electrical
# > Heating vs. KitchenQual
# > Heating vs. Functional
# > Heating vs. FireplaceQu
# > Heating vs. GarageType
# > Heating vs. GarageFinish
# > Heating vs. GarageQual
# > Heating vs. GarageCond
# > Heating vs. PavedDrive
# > Heating vs. PoolQC
# > Heating vs. Fence
# > Heating vs. MiscFeature
# > Heating vs. SaleType
# > Heating vs. SaleCondition
# > Heating vs. MSSubClass
# > Heating vs. OverallQual
# > Heating vs. OverallCond
# > Heating vs. LowQualFinSF
# > Heating vs. BsmtFullBath
# > Heating vs. BsmtHalfBath
# > Heating vs. FullBath
# > Heating vs. HalfBath
# > Heating vs. BedroomAbvGr
# > Heating vs. KitchenAbvGr
# > Heating vs. TotRmsAbvGrd
# > Heating vs. Fireplaces
# > Heating vs. GarageCars
# > Heating vs. 3SsnPorch
# > Heating vs. PoolArea
# > Heating vs. MiscVal
# > Heating vs. MoSold
# > HeatingQC vs. CentralAir
# > HeatingQC vs. Electrical
# > HeatingQC vs. KitchenQual
# > HeatingQC vs. Functional
# > HeatingQC vs. FireplaceQu
# > HeatingQC vs. GarageType
# > HeatingQC vs. GarageFinish
# > HeatingQC vs. GarageQual
# > HeatingQC vs. GarageCond
# > HeatingQC vs. PavedDrive
# > HeatingQC vs. PoolQC
# > HeatingQC vs. Fence
# > HeatingQC vs. MiscFeature
# > HeatingQC vs. SaleType
# > HeatingQC vs. SaleCondition
# > HeatingQC vs. MSSubClass
# > HeatingQC vs. OverallQual
# > HeatingQC vs. OverallCond
# > HeatingQC vs. LowQualFinSF
# > HeatingQC vs. BsmtFullBath
# > HeatingQC vs. BsmtHalfBath
# > HeatingQC vs. FullBath
# > HeatingQC vs. HalfBath
# > HeatingQC vs. BedroomAbvGr
# > HeatingQC vs. KitchenAbvGr
# > HeatingQC vs. TotRmsAbvGrd
# > HeatingQC vs. Fireplaces
# > HeatingQC vs. GarageCars
# > HeatingQC vs. 3SsnPorch
# > HeatingQC vs. PoolArea
# > HeatingQC vs. MiscVal
# > CentralAir vs. Electrical
# > CentralAir vs. KitchenQual
# > CentralAir vs. Functional
# > CentralAir vs. FireplaceQu
# > CentralAir vs. GarageType
# > CentralAir vs. GarageFinish
# > CentralAir vs. GarageQual
# > CentralAir vs. GarageCond
# > CentralAir vs. PavedDrive
# > CentralAir vs. PoolQC
# > CentralAir vs. Fence
# > CentralAir vs. MiscFeature
# > CentralAir vs. SaleType
# > CentralAir vs. SaleCondition
# > CentralAir vs. MSSubClass
# > CentralAir vs. OverallQual
# > CentralAir vs. OverallCond
# > CentralAir vs. LowQualFinSF
# > CentralAir vs. BsmtFullBath
# > CentralAir vs. BsmtHalfBath
# > CentralAir vs. FullBath
# > CentralAir vs. HalfBath
# > CentralAir vs. BedroomAbvGr
# > CentralAir vs. KitchenAbvGr
# > CentralAir vs. TotRmsAbvGrd
# > CentralAir vs. Fireplaces
# > CentralAir vs. GarageCars
# > CentralAir vs. 3SsnPorch
# > CentralAir vs. PoolArea
# > CentralAir vs. MiscVal
# > CentralAir vs. MoSold
# > Electrical vs. KitchenQual
# > Electrical vs. Functional
# > Electrical vs. FireplaceQu
# > Electrical vs. GarageType
# > Electrical vs. GarageFinish
# > Electrical vs. GarageQual
# > Electrical vs. GarageCond
# > Electrical vs. PavedDrive
# > Electrical vs. PoolQC
# > Electrical vs. Fence
# > Electrical vs. MiscFeature
# > Electrical vs. SaleType
# > Electrical vs. SaleCondition
# > Electrical vs. MSSubClass
# > Electrical vs. OverallQual
# > Electrical vs. OverallCond
# > Electrical vs. LowQualFinSF
# > Electrical vs. BsmtFullBath
# > Electrical vs. BsmtHalfBath
# > Electrical vs. FullBath
# > Electrical vs. HalfBath
# > Electrical vs. BedroomAbvGr
# > Electrical vs. KitchenAbvGr
# > Electrical vs. TotRmsAbvGrd
# > Electrical vs. Fireplaces
# > Electrical vs. GarageCars
# > Electrical vs. 3SsnPorch
# > Electrical vs. PoolArea
# > Electrical vs. MiscVal
# > Electrical vs. MoSold
# > KitchenQual vs. Functional
# > KitchenQual vs. FireplaceQu
# > KitchenQual vs. GarageType
# > KitchenQual vs. GarageFinish
# > KitchenQual vs. GarageQual
# > KitchenQual vs. GarageCond
# > KitchenQual vs. PavedDrive
# > KitchenQual vs. PoolQC
# > KitchenQual vs. Fence
# > KitchenQual vs. MiscFeature
# > KitchenQual vs. SaleType
# > KitchenQual vs. SaleCondition
# > KitchenQual vs. MSSubClass
# > KitchenQual vs. OverallQual
# > KitchenQual vs. OverallCond
# > KitchenQual vs. LowQualFinSF
# > KitchenQual vs. BsmtFullBath
# > KitchenQual vs. BsmtHalfBath
# > KitchenQual vs. FullBath
# > KitchenQual vs. HalfBath
# > KitchenQual vs. BedroomAbvGr
# > KitchenQual vs. KitchenAbvGr
# > KitchenQual vs. TotRmsAbvGrd
# > KitchenQual vs. Fireplaces
# > KitchenQual vs. GarageCars
# > KitchenQual vs. 3SsnPorch
# > KitchenQual vs. PoolArea
# > KitchenQual vs. MiscVal
# > Functional vs. FireplaceQu
# > Functional vs. GarageType
# > Functional vs. GarageFinish
# > Functional vs. GarageQual
# > Functional vs. GarageCond
# > Functional vs. PavedDrive
# > Functional vs. PoolQC
# > Functional vs. Fence
# > Functional vs. MiscFeature
# > Functional vs. SaleType
# > Functional vs. SaleCondition
# > Functional vs. MSSubClass
# > Functional vs. OverallQual
# > Functional vs. OverallCond
# > Functional vs. LowQualFinSF
# > Functional vs. BsmtFullBath
# > Functional vs. BsmtHalfBath
# > Functional vs. FullBath
# > Functional vs. HalfBath
# > Functional vs. BedroomAbvGr
# > Functional vs. KitchenAbvGr
# > Functional vs. TotRmsAbvGrd
# > Functional vs. Fireplaces
# > Functional vs. GarageCars
# > Functional vs. 3SsnPorch
# > Functional vs. PoolArea
# > Functional vs. MiscVal
# > Functional vs. MoSold
# > FireplaceQu vs. GarageType
# > FireplaceQu vs. GarageFinish
# > FireplaceQu vs. GarageQual
# > FireplaceQu vs. GarageCond
# > FireplaceQu vs. PavedDrive
# > FireplaceQu vs. PoolQC
# > FireplaceQu vs. Fence
# > FireplaceQu vs. MiscFeature
# > FireplaceQu vs. SaleType
# > FireplaceQu vs. SaleCondition
# > FireplaceQu vs. MSSubClass
# > FireplaceQu vs. OverallQual
# > FireplaceQu vs. OverallCond
# > FireplaceQu vs. LowQualFinSF
# > FireplaceQu vs. BsmtFullBath
# > FireplaceQu vs. BsmtHalfBath
# > FireplaceQu vs. FullBath
# > FireplaceQu vs. HalfBath
# > FireplaceQu vs. BedroomAbvGr
# > FireplaceQu vs. KitchenAbvGr
# > FireplaceQu vs. TotRmsAbvGrd
# > FireplaceQu vs. Fireplaces
# > FireplaceQu vs. GarageCars
# > FireplaceQu vs. 3SsnPorch
# > FireplaceQu vs. PoolArea
# > FireplaceQu vs. MiscVal
# > GarageType vs. GarageFinish
# > GarageType vs. GarageQual
# > GarageType vs. GarageCond
# > GarageType vs. PavedDrive
# > GarageType vs. PoolQC
# > GarageType vs. Fence
# > GarageType vs. MiscFeature
# > GarageType vs. SaleType
# > GarageType vs. SaleCondition
# > GarageType vs. MSSubClass
# > GarageType vs. OverallQual
# > GarageType vs. OverallCond
# > GarageType vs. LowQualFinSF
# > GarageType vs. BsmtFullBath
# > GarageType vs. BsmtHalfBath
# > GarageType vs. FullBath
# > GarageType vs. HalfBath
# > GarageType vs. BedroomAbvGr
# > GarageType vs. KitchenAbvGr
# > GarageType vs. TotRmsAbvGrd
# > GarageType vs. Fireplaces
# > GarageType vs. GarageCars
# > GarageType vs. 3SsnPorch
# > GarageType vs. PoolArea
# > GarageType vs. MiscVal
# > GarageType vs. MoSold
# > GarageFinish vs. GarageQual
# > GarageFinish vs. GarageCond
# > GarageFinish vs. PavedDrive
# > GarageFinish vs. PoolQC
# > GarageFinish vs. Fence
# > GarageFinish vs. MiscFeature
# > GarageFinish vs. SaleType
# > GarageFinish vs. SaleCondition
# > GarageFinish vs. MSSubClass
# > GarageFinish vs. OverallQual
# > GarageFinish vs. OverallCond
# > GarageFinish vs. LowQualFinSF
# > GarageFinish vs. BsmtFullBath
# > GarageFinish vs. BsmtHalfBath
# > GarageFinish vs. FullBath
# > GarageFinish vs. HalfBath
# > GarageFinish vs. BedroomAbvGr
# > GarageFinish vs. KitchenAbvGr
# > GarageFinish vs. TotRmsAbvGrd
# > GarageFinish vs. Fireplaces
# > GarageFinish vs. GarageCars
# > GarageFinish vs. 3SsnPorch
# > GarageFinish vs. PoolArea
# > GarageFinish vs. MiscVal
# > GarageQual vs. GarageCond
# > GarageQual vs. PavedDrive
# > GarageQual vs. PoolQC
# > GarageQual vs. Fence
# > GarageQual vs. MiscFeature
# > GarageQual vs. SaleType
# > GarageQual vs. SaleCondition
# > GarageQual vs. MSSubClass
# > GarageQual vs. OverallQual
# > GarageQual vs. OverallCond
# > GarageQual vs. LowQualFinSF
# > GarageQual vs. BsmtFullBath
# > GarageQual vs. BsmtHalfBath
# > GarageQual vs. FullBath
# > GarageQual vs. HalfBath
# > GarageQual vs. BedroomAbvGr
# > GarageQual vs. KitchenAbvGr
# > GarageQual vs. TotRmsAbvGrd
# > GarageQual vs. Fireplaces
# > GarageQual vs. GarageCars
# > GarageQual vs. 3SsnPorch
# > GarageQual vs. PoolArea
# > GarageQual vs. MiscVal
# > GarageQual vs. MoSold
# > GarageCond vs. PavedDrive
# > GarageCond vs. PoolQC
# > GarageCond vs. Fence
# > GarageCond vs. MiscFeature
# > GarageCond vs. SaleType
# > GarageCond vs. SaleCondition
# > GarageCond vs. MSSubClass
# > GarageCond vs. OverallQual
# > GarageCond vs. OverallCond
# > GarageCond vs. LowQualFinSF
# > GarageCond vs. BsmtFullBath
# > GarageCond vs. BsmtHalfBath
# > GarageCond vs. FullBath
# > GarageCond vs. HalfBath
# > GarageCond vs. BedroomAbvGr
# > GarageCond vs. KitchenAbvGr
# > GarageCond vs. TotRmsAbvGrd
# > GarageCond vs. Fireplaces
# > GarageCond vs. GarageCars
# > GarageCond vs. 3SsnPorch
# > GarageCond vs. PoolArea
# > GarageCond vs. MiscVal
# > GarageCond vs. MoSold
# > PavedDrive vs. PoolQC
# > PavedDrive vs. Fence
# > PavedDrive vs. MiscFeature
# > PavedDrive vs. SaleType
# > PavedDrive vs. SaleCondition
# > PavedDrive vs. MSSubClass
# > PavedDrive vs. OverallQual
# > PavedDrive vs. OverallCond
# > PavedDrive vs. LowQualFinSF
# > PavedDrive vs. BsmtFullBath
# > PavedDrive vs. BsmtHalfBath
# > PavedDrive vs. FullBath
# > PavedDrive vs. HalfBath
# > PavedDrive vs. BedroomAbvGr
# > PavedDrive vs. KitchenAbvGr
# > PavedDrive vs. TotRmsAbvGrd
# > PavedDrive vs. Fireplaces
# > PavedDrive vs. GarageCars
# > PavedDrive vs. 3SsnPorch
# > PavedDrive vs. PoolArea
# > PavedDrive vs. MiscVal
# > PavedDrive vs. MoSold
# > PoolQC vs. Fence
# > PoolQC vs. MiscFeature
# > PoolQC vs. SaleType
# > PoolQC vs. SaleCondition
# > PoolQC vs. MSSubClass
# > PoolQC vs. OverallQual
# > PoolQC vs. OverallCond
# > PoolQC vs. LowQualFinSF
# > PoolQC vs. BsmtFullBath
# > PoolQC vs. BsmtHalfBath
# > PoolQC vs. FullBath
# > PoolQC vs. HalfBath
# > PoolQC vs. BedroomAbvGr
# > PoolQC vs. KitchenAbvGr
# > PoolQC vs. TotRmsAbvGrd
# > PoolQC vs. Fireplaces
# > PoolQC vs. GarageCars
# > PoolQC vs. 3SsnPorch
# > PoolQC vs. PoolArea
# > PoolQC vs. MiscVal
# > PoolQC vs. MoSold
# > Fence vs. MiscFeature
# > Fence vs. SaleType
# > Fence vs. SaleCondition
# > Fence vs. MSSubClass
# > Fence vs. OverallQual
# > Fence vs. OverallCond
# > Fence vs. LowQualFinSF
# > Fence vs. BsmtFullBath
# > Fence vs. BsmtHalfBath
# > Fence vs. FullBath
# > Fence vs. HalfBath
# > Fence vs. BedroomAbvGr
# > Fence vs. KitchenAbvGr
# > Fence vs. TotRmsAbvGrd
# > Fence vs. Fireplaces
# > Fence vs. GarageCars
# > Fence vs. 3SsnPorch
# > Fence vs. PoolArea
# > Fence vs. MiscVal
# > Fence vs. MoSold
# > MiscFeature vs. SaleType
# > MiscFeature vs. SaleCondition
# > MiscFeature vs. MSSubClass
# > MiscFeature vs. OverallQual
# > MiscFeature vs. OverallCond
# > MiscFeature vs. LowQualFinSF
# > MiscFeature vs. BsmtFullBath
# > MiscFeature vs. BsmtHalfBath
# > MiscFeature vs. FullBath
# > MiscFeature vs. HalfBath
# > MiscFeature vs. BedroomAbvGr
# > MiscFeature vs. KitchenAbvGr
# > MiscFeature vs. TotRmsAbvGrd
# > MiscFeature vs. Fireplaces
# > MiscFeature vs. GarageCars
# > MiscFeature vs. 3SsnPorch
# > MiscFeature vs. PoolArea
# > MiscFeature vs. MiscVal
# > MiscFeature vs. MoSold
# > SaleType vs. SaleCondition
# > SaleType vs. MSSubClass
# > SaleType vs. OverallQual
# > SaleType vs. OverallCond
# > SaleType vs. LowQualFinSF
# > SaleType vs. BsmtFullBath
# > SaleType vs. BsmtHalfBath
# > SaleType vs. FullBath
# > SaleType vs. HalfBath
# > SaleType vs. BedroomAbvGr
# > SaleType vs. KitchenAbvGr
# > SaleType vs. TotRmsAbvGrd
# > SaleType vs. Fireplaces
# > SaleType vs. GarageCars
# > SaleType vs. 3SsnPorch
# > SaleType vs. PoolArea
# > SaleType vs. MiscVal
# > SaleType vs. MoSold
# > SaleCondition vs. MSSubClass
# > SaleCondition vs. OverallQual
# > SaleCondition vs. OverallCond
# > SaleCondition vs. LowQualFinSF
# > SaleCondition vs. BsmtFullBath
# > SaleCondition vs. BsmtHalfBath
# > SaleCondition vs. FullBath
# > SaleCondition vs. HalfBath
# > SaleCondition vs. BedroomAbvGr
# > SaleCondition vs. KitchenAbvGr
# > SaleCondition vs. TotRmsAbvGrd
# > SaleCondition vs. Fireplaces
# > SaleCondition vs. GarageCars
# > SaleCondition vs. 3SsnPorch
# > SaleCondition vs. PoolArea
# > SaleCondition vs. MiscVal
# > SaleCondition vs. MoSold
# > MSSubClass vs. OverallQual
# > MSSubClass vs. OverallCond
# > MSSubClass vs. LowQualFinSF
# > MSSubClass vs. BsmtFullBath
# > MSSubClass vs. BsmtHalfBath
# > MSSubClass vs. FullBath
# > MSSubClass vs. HalfBath
# > MSSubClass vs. BedroomAbvGr
# > MSSubClass vs. KitchenAbvGr
# > MSSubClass vs. TotRmsAbvGrd
# > MSSubClass vs. Fireplaces
# > MSSubClass vs. GarageCars
# > MSSubClass vs. 3SsnPorch
# > MSSubClass vs. PoolArea
# > MSSubClass vs. MiscVal
# > OverallQual vs. OverallCond
# > OverallQual vs. LowQualFinSF
# > OverallQual vs. BsmtFullBath
# > OverallQual vs. BsmtHalfBath
# > OverallQual vs. FullBath
# > OverallQual vs. HalfBath
# > OverallQual vs. BedroomAbvGr
# > OverallQual vs. KitchenAbvGr
# > OverallQual vs. Fireplaces
# > OverallQual vs. GarageCars
# > OverallQual vs. 3SsnPorch
# > OverallQual vs. PoolArea
# > OverallQual vs. MiscVal
# > OverallCond vs. LowQualFinSF
# > OverallCond vs. BsmtFullBath
# > OverallCond vs. BsmtHalfBath
# > OverallCond vs. FullBath
# > OverallCond vs. HalfBath
# > OverallCond vs. BedroomAbvGr
# > OverallCond vs. KitchenAbvGr
# > OverallCond vs. TotRmsAbvGrd
# > OverallCond vs. Fireplaces
# > OverallCond vs. GarageCars
# > OverallCond vs. 3SsnPorch
# > OverallCond vs. PoolArea
# > OverallCond vs. MiscVal
# > LowQualFinSF vs. BsmtFullBath
# > LowQualFinSF vs. BsmtHalfBath
# > LowQualFinSF vs. FullBath
# > LowQualFinSF vs. HalfBath
# > LowQualFinSF vs. BedroomAbvGr
# > LowQualFinSF vs. KitchenAbvGr
# > LowQualFinSF vs. TotRmsAbvGrd
# > LowQualFinSF vs. Fireplaces
# > LowQualFinSF vs. GarageCars
# > LowQualFinSF vs. 3SsnPorch
# > LowQualFinSF vs. PoolArea
# > LowQualFinSF vs. MiscVal
# > LowQualFinSF vs. MoSold
# > BsmtFullBath vs. BsmtHalfBath
# > BsmtFullBath vs. FullBath
# > BsmtFullBath vs. HalfBath
# > BsmtFullBath vs. BedroomAbvGr
# > BsmtFullBath vs. KitchenAbvGr
# > BsmtFullBath vs. TotRmsAbvGrd
# > BsmtFullBath vs. Fireplaces
# > BsmtFullBath vs. GarageCars
# > BsmtFullBath vs. 3SsnPorch
# > BsmtFullBath vs. PoolArea
# > BsmtFullBath vs. MiscVal
# > BsmtFullBath vs. MoSold
# > BsmtHalfBath vs. FullBath
# > BsmtHalfBath vs. HalfBath
# > BsmtHalfBath vs. BedroomAbvGr
# > BsmtHalfBath vs. KitchenAbvGr
# > BsmtHalfBath vs. TotRmsAbvGrd
# > BsmtHalfBath vs. Fireplaces
# > BsmtHalfBath vs. GarageCars
# > BsmtHalfBath vs. 3SsnPorch
# > BsmtHalfBath vs. PoolArea
# > BsmtHalfBath vs. MiscVal
# > BsmtHalfBath vs. MoSold
# > FullBath vs. HalfBath
# > FullBath vs. BedroomAbvGr
# > FullBath vs. KitchenAbvGr
# > FullBath vs. TotRmsAbvGrd
# > FullBath vs. Fireplaces
# > FullBath vs. GarageCars
# > FullBath vs. 3SsnPorch
# > FullBath vs. PoolArea
# > FullBath vs. MiscVal
# > HalfBath vs. BedroomAbvGr
# > HalfBath vs. KitchenAbvGr
# > HalfBath vs. TotRmsAbvGrd
# > HalfBath vs. Fireplaces
# > HalfBath vs. GarageCars
# ...
# > TotalBsmtSF vs. HeatingQC
# > TotalBsmtSF vs. CentralAir
# > TotalBsmtSF vs. Electrical
# > TotalBsmtSF vs. KitchenQual
# > TotalBsmtSF vs. Functional
# > TotalBsmtSF vs. FireplaceQu
# > TotalBsmtSF vs. GarageType
# > TotalBsmtSF vs. GarageFinish
# > TotalBsmtSF vs. GarageQual
# > TotalBsmtSF vs. GarageCond
# > TotalBsmtSF vs. PavedDrive
# > TotalBsmtSF vs. PoolQC
# > TotalBsmtSF vs. Fence
# > TotalBsmtSF vs. MiscFeature
# > TotalBsmtSF vs. SaleType
# > TotalBsmtSF vs. SaleCondition
# > TotalBsmtSF vs. MSSubClass
# > TotalBsmtSF vs. OverallQual
# > TotalBsmtSF vs. OverallCond
# > TotalBsmtSF vs. LowQualFinSF
# > TotalBsmtSF vs. BsmtFullBath
# > TotalBsmtSF vs. FullBath
# > TotalBsmtSF vs. BedroomAbvGr
# > TotalBsmtSF vs. KitchenAbvGr
# > TotalBsmtSF vs. TotRmsAbvGrd
# > TotalBsmtSF vs. Fireplaces
# > TotalBsmtSF vs. GarageCars
# > TotalBsmtSF vs. 3SsnPorch
# > TotalBsmtSF vs. PoolArea
# > TotalBsmtSF vs. MiscVal
# > TotalBsmtSF vs. MoSold
# > 1stFlrSF vs. MSZoning
# > 1stFlrSF vs. Alley
# > 1stFlrSF vs. LotShape
# > 1stFlrSF vs. LandContour
# > 1stFlrSF vs. Utilities
# > 1stFlrSF vs. LotConfig
# > 1stFlrSF vs. LandSlope
# > 1stFlrSF vs. Neighborhood
# > 1stFlrSF vs. Condition1
# > 1stFlrSF vs. Condition2
# > 1stFlrSF vs. BldgType
# > 1stFlrSF vs. HouseStyle
# > 1stFlrSF vs. RoofStyle
# > 1stFlrSF vs. RoofMatl
# > 1stFlrSF vs. Exterior1st
# > 1stFlrSF vs. Exterior2nd
# > 1stFlrSF vs. MasVnrType
# > 1stFlrSF vs. ExterQual
# > 1stFlrSF vs. ExterCond
# > 1stFlrSF vs. Foundation
# > 1stFlrSF vs. BsmtQual
# > 1stFlrSF vs. BsmtCond
# > 1stFlrSF vs. BsmtExposure
# > 1stFlrSF vs. BsmtFinType1
# > 1stFlrSF vs. BsmtFinType2
# > 1stFlrSF vs. Heating
# > 1stFlrSF vs. HeatingQC
# > 1stFlrSF vs. CentralAir
# > 1stFlrSF vs. Electrical
# > 1stFlrSF vs. KitchenQual
# > 1stFlrSF vs. Functional
# > 1stFlrSF vs. FireplaceQu
# > 1stFlrSF vs. GarageType
# > 1stFlrSF vs. GarageFinish
# > 1stFlrSF vs. GarageQual
# > 1stFlrSF vs. GarageCond
# > 1stFlrSF vs. PavedDrive
# > 1stFlrSF vs. PoolQC
# > 1stFlrSF vs. Fence
# > 1stFlrSF vs. MiscFeature
# > 1stFlrSF vs. SaleType
# > 1stFlrSF vs. SaleCondition
# > 1stFlrSF vs. MSSubClass
# > 1stFlrSF vs. OverallQual
# > 1stFlrSF vs. OverallCond
# > 1stFlrSF vs. LowQualFinSF
# > 1stFlrSF vs. BsmtFullBath
# > 1stFlrSF vs. FullBath
# > 1stFlrSF vs. BedroomAbvGr
# > 1stFlrSF vs. KitchenAbvGr
# > 1stFlrSF vs. TotRmsAbvGrd
# > 1stFlrSF vs. Fireplaces
# > 1stFlrSF vs. GarageCars
# > 1stFlrSF vs. 3SsnPorch
# > 1stFlrSF vs. PoolArea
# > 1stFlrSF vs. MiscVal
# > 2ndFlrSF vs. MSZoning
# > 2ndFlrSF vs. Street
# > 2ndFlrSF vs. Alley
# > 2ndFlrSF vs. LotShape
# > 2ndFlrSF vs. LandContour
# > 2ndFlrSF vs. Utilities
# > 2ndFlrSF vs. LotConfig
# > 2ndFlrSF vs. LandSlope
# > 2ndFlrSF vs. Neighborhood
# > 2ndFlrSF vs. Condition1
# > 2ndFlrSF vs. Condition2
# > 2ndFlrSF vs. BldgType
# > 2ndFlrSF vs. HouseStyle
# > 2ndFlrSF vs. RoofStyle
# > 2ndFlrSF vs. RoofMatl
# > 2ndFlrSF vs. Exterior1st
# > 2ndFlrSF vs. Exterior2nd
# > 2ndFlrSF vs. MasVnrType
# > 2ndFlrSF vs. ExterQual
# > 2ndFlrSF vs. ExterCond
# > 2ndFlrSF vs. Foundation
# > 2ndFlrSF vs. BsmtQual
# > 2ndFlrSF vs. BsmtCond
# > 2ndFlrSF vs. BsmtExposure
# > 2ndFlrSF vs. BsmtFinType1
# > 2ndFlrSF vs. BsmtFinType2
# > 2ndFlrSF vs. Heating
# > 2ndFlrSF vs. HeatingQC
# > 2ndFlrSF vs. Electrical
# > 2ndFlrSF vs. KitchenQual
# > 2ndFlrSF vs. Functional
# > 2ndFlrSF vs. FireplaceQu
# > 2ndFlrSF vs. GarageType
# > 2ndFlrSF vs. GarageFinish
# > 2ndFlrSF vs. GarageQual
# > 2ndFlrSF vs. GarageCond
# > 2ndFlrSF vs. PavedDrive
# > 2ndFlrSF vs. PoolQC
# > 2ndFlrSF vs. Fence
# > 2ndFlrSF vs. MiscFeature
# > 2ndFlrSF vs. SaleType
# > 2ndFlrSF vs. SaleCondition
# > 2ndFlrSF vs. MSSubClass
# > 2ndFlrSF vs. OverallQual
# > 2ndFlrSF vs. OverallCond
# > 2ndFlrSF vs. LowQualFinSF
# > 2ndFlrSF vs. BsmtFullBath
# > 2ndFlrSF vs. BsmtHalfBath
# > 2ndFlrSF vs. FullBath
# > 2ndFlrSF vs. HalfBath
# > 2ndFlrSF vs. BedroomAbvGr
# > 2ndFlrSF vs. KitchenAbvGr
# > 2ndFlrSF vs. TotRmsAbvGrd
# > 2ndFlrSF vs. Fireplaces
# > 2ndFlrSF vs. GarageCars
# > 2ndFlrSF vs. 3SsnPorch
# > 2ndFlrSF vs. PoolArea
# > 2ndFlrSF vs. MiscVal
# > 2ndFlrSF vs. MoSold
# > GrLivArea vs. MSZoning
# > GrLivArea vs. Street
# > GrLivArea vs. LotShape
# > GrLivArea vs. Utilities
# > GrLivArea vs. LotConfig
# > GrLivArea vs. Neighborhood
# > GrLivArea vs. Condition1
# > GrLivArea vs. Condition2
# > GrLivArea vs. BldgType
# > GrLivArea vs. HouseStyle
# > GrLivArea vs. RoofStyle
# > GrLivArea vs. RoofMatl
# > GrLivArea vs. Exterior1st
# > GrLivArea vs. Exterior2nd
# > GrLivArea vs. MasVnrType
# > GrLivArea vs. ExterQual
# > GrLivArea vs. ExterCond
# > GrLivArea vs. Foundation
# > GrLivArea vs. BsmtQual
# > GrLivArea vs. BsmtCond
# > GrLivArea vs. BsmtExposure
# > GrLivArea vs. BsmtFinType1
# > GrLivArea vs. BsmtFinType2
# > GrLivArea vs. Heating
# > GrLivArea vs. HeatingQC
# > GrLivArea vs. CentralAir
# > GrLivArea vs. Electrical
# > GrLivArea vs. KitchenQual
# > GrLivArea vs. Functional
# > GrLivArea vs. FireplaceQu
# > GrLivArea vs. GarageType
# > GrLivArea vs. GarageFinish
# > GrLivArea vs. GarageQual
# > GrLivArea vs. GarageCond
# > GrLivArea vs. PavedDrive
# > GrLivArea vs. PoolQC
# > GrLivArea vs. Fence
# > GrLivArea vs. MiscFeature
# > GrLivArea vs. SaleType
# > GrLivArea vs. SaleCondition
# > GrLivArea vs. MSSubClass
# > GrLivArea vs. OverallQual
# > GrLivArea vs. OverallCond
# > GrLivArea vs. LowQualFinSF
# > GrLivArea vs. BsmtFullBath
# > GrLivArea vs. BsmtHalfBath
# > GrLivArea vs. FullBath
# > GrLivArea vs. HalfBath
# > GrLivArea vs. BedroomAbvGr
# > GrLivArea vs. KitchenAbvGr
# > GrLivArea vs. TotRmsAbvGrd
# > GrLivArea vs. Fireplaces
# > GrLivArea vs. GarageCars
# > GrLivArea vs. 3SsnPorch
# > GrLivArea vs. PoolArea
# > GrLivArea vs. MiscVal
# > GrLivArea vs. MoSold
# > GarageYrBlt vs. MSZoning
# > GarageYrBlt vs. Street
# > GarageYrBlt vs. Alley
# > GarageYrBlt vs. LandContour
# > GarageYrBlt vs. Neighborhood
# > GarageYrBlt vs. Condition1
# > GarageYrBlt vs. Condition2
# > GarageYrBlt vs. BldgType
# > GarageYrBlt vs. HouseStyle
# > GarageYrBlt vs. RoofStyle
# > GarageYrBlt vs. RoofMatl
# > GarageYrBlt vs. Exterior1st
# > GarageYrBlt vs. Exterior2nd
# > GarageYrBlt vs. MasVnrType
# > GarageYrBlt vs. ExterQual
# > GarageYrBlt vs. ExterCond
# > GarageYrBlt vs. Foundation
# > GarageYrBlt vs. BsmtQual
# > GarageYrBlt vs. BsmtCond
# > GarageYrBlt vs. BsmtExposure
# > GarageYrBlt vs. BsmtFinType1
# > GarageYrBlt vs. BsmtFinType2
# > GarageYrBlt vs. Heating
# > GarageYrBlt vs. HeatingQC
# > GarageYrBlt vs. CentralAir
# > GarageYrBlt vs. Electrical
# > GarageYrBlt vs. KitchenQual
# > GarageYrBlt vs. Functional
# > GarageYrBlt vs. FireplaceQu
# > GarageYrBlt vs. GarageType
# > GarageYrBlt vs. GarageFinish
# > GarageYrBlt vs. GarageQual
# > GarageYrBlt vs. GarageCond
# > GarageYrBlt vs. PavedDrive
# > GarageYrBlt vs. MiscFeature
# > GarageYrBlt vs. SaleType
# > GarageYrBlt vs. SaleCondition
# > GarageYrBlt vs. MSSubClass
# > GarageYrBlt vs. OverallQual
# > GarageYrBlt vs. OverallCond
# > GarageYrBlt vs. LowQualFinSF
# > GarageYrBlt vs. BsmtFullBath
# > GarageYrBlt vs. BsmtHalfBath
# > GarageYrBlt vs. HalfBath
# > GarageYrBlt vs. BedroomAbvGr
# > GarageYrBlt vs. KitchenAbvGr
# > GarageYrBlt vs. TotRmsAbvGrd
# > GarageYrBlt vs. Fireplaces
# > GarageYrBlt vs. GarageCars
# > GarageYrBlt vs. MiscVal
# > GarageYrBlt vs. MoSold
# > GarageArea vs. MSZoning
# > GarageArea vs. Street
# > GarageArea vs. Alley
# > GarageArea vs. LotShape
# > GarageArea vs. LandContour
# > GarageArea vs. Utilities
# > GarageArea vs. LotConfig
# > GarageArea vs. Neighborhood
# > GarageArea vs. Condition1
# > GarageArea vs. Condition2
# > GarageArea vs. BldgType
# > GarageArea vs. HouseStyle
# > GarageArea vs. RoofStyle
# > GarageArea vs. RoofMatl
# > GarageArea vs. Exterior1st
# > GarageArea vs. Exterior2nd
# > GarageArea vs. MasVnrType
# > GarageArea vs. ExterQual
# > GarageArea vs. ExterCond
# > GarageArea vs. Foundation
# > GarageArea vs. BsmtQual
# > GarageArea vs. BsmtCond
# > GarageArea vs. BsmtExposure
# > GarageArea vs. BsmtFinType1
# > GarageArea vs. BsmtFinType2
# > GarageArea vs. Heating
# > GarageArea vs. HeatingQC
# > GarageArea vs. CentralAir
# > GarageArea vs. Electrical
# > GarageArea vs. KitchenQual
# > GarageArea vs. Functional
# > GarageArea vs. FireplaceQu
# > GarageArea vs. GarageType
# > GarageArea vs. GarageFinish
# > GarageArea vs. GarageQual
# > GarageArea vs. GarageCond
# > GarageArea vs. PavedDrive
# > GarageArea vs. PoolQC
# > GarageArea vs. Fence
# > GarageArea vs. MiscFeature
# > GarageArea vs. SaleType
# > GarageArea vs. SaleCondition
# > GarageArea vs. MSSubClass
# > GarageArea vs. OverallQual
# > GarageArea vs. OverallCond
# > GarageArea vs. LowQualFinSF
# > GarageArea vs. BsmtFullBath
# > GarageArea vs. BsmtHalfBath
# > GarageArea vs. FullBath
# > GarageArea vs. HalfBath
# > GarageArea vs. BedroomAbvGr
# > GarageArea vs. KitchenAbvGr
# > GarageArea vs. TotRmsAbvGrd
# > GarageArea vs. Fireplaces
# > GarageArea vs. GarageCars
# > GarageArea vs. 3SsnPorch
# > GarageArea vs. PoolArea
# > GarageArea vs. MiscVal
# > GarageArea vs. MoSold
# > WoodDeckSF vs. MSZoning
# > WoodDeckSF vs. Street
# > WoodDeckSF vs. Alley
# > WoodDeckSF vs. LotShape
# > WoodDeckSF vs. LandContour
# > WoodDeckSF vs. Utilities
# > WoodDeckSF vs. LotConfig
# > WoodDeckSF vs. LandSlope
# > WoodDeckSF vs. Neighborhood
# > WoodDeckSF vs. Condition1
# > WoodDeckSF vs. Condition2
# > WoodDeckSF vs. BldgType
# > WoodDeckSF vs. HouseStyle
# > WoodDeckSF vs. RoofStyle
# > WoodDeckSF vs. RoofMatl
# > WoodDeckSF vs. Exterior1st
# > WoodDeckSF vs. Exterior2nd
# > WoodDeckSF vs. MasVnrType
# > WoodDeckSF vs. ExterQual
# > WoodDeckSF vs. ExterCond
# > WoodDeckSF vs. Foundation
# > WoodDeckSF vs. BsmtQual
# > WoodDeckSF vs. BsmtCond
# > WoodDeckSF vs. BsmtExposure
# > WoodDeckSF vs. BsmtFinType1
# > WoodDeckSF vs. BsmtFinType2
# > WoodDeckSF vs. Heating
# > WoodDeckSF vs. HeatingQC
# > WoodDeckSF vs. CentralAir
# > WoodDeckSF vs. Electrical
# > WoodDeckSF vs. KitchenQual
# > WoodDeckSF vs. Functional
# > WoodDeckSF vs. FireplaceQu
# > WoodDeckSF vs. GarageType
# > WoodDeckSF vs. GarageFinish
# > WoodDeckSF vs. GarageQual
# > WoodDeckSF vs. GarageCond
# > WoodDeckSF vs. PavedDrive
# > WoodDeckSF vs. PoolQC
# > WoodDeckSF vs. Fence
# > WoodDeckSF vs. MiscFeature
# > WoodDeckSF vs. SaleType
# > WoodDeckSF vs. SaleCondition
# > WoodDeckSF vs. MSSubClass
# > WoodDeckSF vs. OverallQual
# > WoodDeckSF vs. OverallCond
# > WoodDeckSF vs. LowQualFinSF
# > WoodDeckSF vs. BsmtFullBath
# > WoodDeckSF vs. BsmtHalfBath
# > WoodDeckSF vs. FullBath
# > WoodDeckSF vs. HalfBath
# > WoodDeckSF vs. BedroomAbvGr
# > WoodDeckSF vs. KitchenAbvGr
# > WoodDeckSF vs. TotRmsAbvGrd
# > WoodDeckSF vs. Fireplaces
# > WoodDeckSF vs. GarageCars
# > WoodDeckSF vs. 3SsnPorch
# > WoodDeckSF vs. PoolArea
# > WoodDeckSF vs. MiscVal
# > WoodDeckSF vs. MoSold
# > OpenPorchSF vs. MSZoning
# > OpenPorchSF vs. Street
# > OpenPorchSF vs. Alley
# > OpenPorchSF vs. LotShape
# > OpenPorchSF vs. LandContour
# > OpenPorchSF vs. Utilities
# > OpenPorchSF vs. LotConfig
# > OpenPorchSF vs. LandSlope
# > OpenPorchSF vs. Neighborhood
# > OpenPorchSF vs. Condition1
# > OpenPorchSF vs. Condition2
# > OpenPorchSF vs. BldgType
# > OpenPorchSF vs. HouseStyle
# > OpenPorchSF vs. RoofStyle
# > OpenPorchSF vs. RoofMatl
# > OpenPorchSF vs. Exterior1st
# > OpenPorchSF vs. Exterior2nd
# > OpenPorchSF vs. MasVnrType
# > OpenPorchSF vs. ExterQual
# > OpenPorchSF vs. ExterCond
# > OpenPorchSF vs. Foundation
# > OpenPorchSF vs. BsmtQual
# > OpenPorchSF vs. BsmtCond
# > OpenPorchSF vs. BsmtExposure
# > OpenPorchSF vs. BsmtFinType1
# > OpenPorchSF vs. BsmtFinType2
# > OpenPorchSF vs. Heating
# > OpenPorchSF vs. HeatingQC
# > OpenPorchSF vs. CentralAir
# > OpenPorchSF vs. Electrical
# > OpenPorchSF vs. KitchenQual
# > OpenPorchSF vs. Functional
# > OpenPorchSF vs. FireplaceQu
# > OpenPorchSF vs. GarageType
# > OpenPorchSF vs. GarageFinish
# > OpenPorchSF vs. GarageQual
# > OpenPorchSF vs. GarageCond
# > OpenPorchSF vs. PavedDrive
# > OpenPorchSF vs. PoolQC
# > OpenPorchSF vs. Fence
# > OpenPorchSF vs. MiscFeature
# > OpenPorchSF vs. SaleType
# > OpenPorchSF vs. SaleCondition
# > OpenPorchSF vs. MSSubClass
# > OpenPorchSF vs. OverallQual
# > OpenPorchSF vs. OverallCond
# > OpenPorchSF vs. LowQualFinSF
# > OpenPorchSF vs. BsmtFullBath
# > OpenPorchSF vs. BsmtHalfBath
# > OpenPorchSF vs. FullBath
# > OpenPorchSF vs. HalfBath
# > OpenPorchSF vs. BedroomAbvGr
# > OpenPorchSF vs. KitchenAbvGr
# > OpenPorchSF vs. TotRmsAbvGrd
# > OpenPorchSF vs. Fireplaces
# > OpenPorchSF vs. GarageCars
# > OpenPorchSF vs. 3SsnPorch
# > OpenPorchSF vs. PoolArea
# > OpenPorchSF vs. MiscVal
# > OpenPorchSF vs. MoSold
# > EnclosedPorch vs. MSZoning
# > EnclosedPorch vs. Street
# > EnclosedPorch vs. Alley
# > EnclosedPorch vs. LotShape
# > EnclosedPorch vs. LandContour
# > EnclosedPorch vs. Utilities
# > EnclosedPorch vs. LotConfig
# > EnclosedPorch vs. LandSlope
# > EnclosedPorch vs. Neighborhood
# > EnclosedPorch vs. Condition1
# > EnclosedPorch vs. Condition2
# > EnclosedPorch vs. BldgType
# > EnclosedPorch vs. HouseStyle
# > EnclosedPorch vs. RoofStyle
# > EnclosedPorch vs. RoofMatl
# > EnclosedPorch vs. Exterior1st
# > EnclosedPorch vs. Exterior2nd
# > EnclosedPorch vs. MasVnrType
# > EnclosedPorch vs. ExterQual
# > EnclosedPorch vs. ExterCond
# > EnclosedPorch vs. Foundation
# > EnclosedPorch vs. BsmtQual
# > EnclosedPorch vs. BsmtCond
# > EnclosedPorch vs. BsmtExposure
# > EnclosedPorch vs. BsmtFinType1
# > EnclosedPorch vs. BsmtFinType2
# > EnclosedPorch vs. Heating
# > EnclosedPorch vs. HeatingQC
# > EnclosedPorch vs. CentralAir
# > EnclosedPorch vs. Electrical
# > EnclosedPorch vs. KitchenQual
# > EnclosedPorch vs. Functional
# > EnclosedPorch vs. FireplaceQu
# > EnclosedPorch vs. GarageType
# > EnclosedPorch vs. GarageFinish
# > EnclosedPorch vs. GarageQual
# > EnclosedPorch vs. GarageCond
# > EnclosedPorch vs. PavedDrive
# > EnclosedPorch vs. PoolQC
# > EnclosedPorch vs. Fence
# > EnclosedPorch vs. MiscFeature
# > EnclosedPorch vs. SaleType
# > EnclosedPorch vs. SaleCondition
# > EnclosedPorch vs. MSSubClass
# > EnclosedPorch vs. OverallQual
# > EnclosedPorch vs. OverallCond
# > EnclosedPorch vs. LowQualFinSF
# > EnclosedPorch vs. BsmtFullBath
# > EnclosedPorch vs. BsmtHalfBath
# > EnclosedPorch vs. FullBath
# > EnclosedPorch vs. HalfBath
# > EnclosedPorch vs. BedroomAbvGr
# > EnclosedPorch vs. KitchenAbvGr
# > EnclosedPorch vs. TotRmsAbvGrd
# > EnclosedPorch vs. Fireplaces
# > EnclosedPorch vs. GarageCars
# > EnclosedPorch vs. 3SsnPorch
# > EnclosedPorch vs. PoolArea
# > EnclosedPorch vs. MiscVal
# > EnclosedPorch vs. MoSold
# > ScreenPorch vs. MSZoning
# > ScreenPorch vs. Street
# > ScreenPorch vs. Alley
# > ScreenPorch vs. LotShape
# > ScreenPorch vs. LandContour
# > ScreenPorch vs. Utilities
# > ScreenPorch vs. LotConfig
# > ScreenPorch vs. LandSlope
# > ScreenPorch vs. Neighborhood
# > ScreenPorch vs. Condition1
# > ScreenPorch vs. Condition2
# > ScreenPorch vs. BldgType
# > ScreenPorch vs. HouseStyle
# > ScreenPorch vs. RoofStyle
# > ScreenPorch vs. RoofMatl
# > ScreenPorch vs. Exterior1st
# > ScreenPorch vs. Exterior2nd
# > ScreenPorch vs. MasVnrType
# > ScreenPorch vs. ExterQual
# > ScreenPorch vs. ExterCond
# > ScreenPorch vs. Foundation
# > ScreenPorch vs. BsmtQual
# > ScreenPorch vs. BsmtCond
# > ScreenPorch vs. BsmtExposure
# > ScreenPorch vs. BsmtFinType1
# > ScreenPorch vs. BsmtFinType2
# > ScreenPorch vs. Heating
# > ScreenPorch vs. HeatingQC
# > ScreenPorch vs. CentralAir
# > ScreenPorch vs. Electrical
# > ScreenPorch vs. KitchenQual
# > ScreenPorch vs. Functional
# > ScreenPorch vs. FireplaceQu
# > ScreenPorch vs. GarageType
# > ScreenPorch vs. GarageFinish
# > ScreenPorch vs. GarageQual
# > ScreenPorch vs. GarageCond
# > ScreenPorch vs. PavedDrive
# > ScreenPorch vs. PoolQC
# > ScreenPorch vs. Fence
# > ScreenPorch vs. MiscFeature
# > ScreenPorch vs. SaleType
# > ScreenPorch vs. SaleCondition
# > ScreenPorch vs. MSSubClass
# > ScreenPorch vs. OverallQual
# > ScreenPorch vs. OverallCond
# > ScreenPorch vs. LowQualFinSF
# > ScreenPorch vs. BsmtFullBath
# > ScreenPorch vs. BsmtHalfBath
# > ScreenPorch vs. FullBath
# > ScreenPorch vs. HalfBath
# > ScreenPorch vs. BedroomAbvGr
# > ScreenPorch vs. KitchenAbvGr
# > ScreenPorch vs. TotRmsAbvGrd
# > ScreenPorch vs. Fireplaces
# > ScreenPorch vs. GarageCars
# > ScreenPorch vs. 3SsnPorch
# > ScreenPorch vs. PoolArea
# > ScreenPorch vs. MiscVal
# > ScreenPorch vs. MoSold
# 4.26 Minutes
# Model Training:
# > Transforming The Training Data
# > Extracting Time Features
# > Transforming Categorical Features
# > Removing Constant Features
# > Scaling Features
# > Training Lasso
# 3.29 Seconds
# Model Performance:
# > Transforming The Testing Data
# > Scoring The Model
# 3.15 Seconds
# Model Indicators:
# > Extracting Important Features
# 0.46 Seconds
# Model Prediction:
# > Transforming The New Data
# > Getting Predictions
# 0.77 Seconds
# Model Monitoring:
# > Computing Feature Drift
# 1.13 Seconds
#
# Model Performance:
# R2: 0.8866623722766908
# RMSE: 23162.385221367083
# In Control: 97.59%

# %%
# model diagnostics
print("Model Indicators:")
for i, indicator in enumerate(model.indicators["Indicator"][:10].tolist()):
    print(f"{i+1}. {indicator}")
print(" ")
print("Feature Drift:")
for i, feature in enumerate(model.drift.loc[model.drift["pvalue"] < 0.05, "Feature"][:10].tolist()):
    print(f"{i+1}. {feature}")
if model.drift.loc[model.drift["pvalue"] < 0.05].shape[0] == 0:
    print("None")
# Out:
# Model Indicators:
# 1. RoofMatl_ClyTile
# 2. GrLivArea
# 3. Condition2_PosN
# 4. OverallQual_10
# 5. OverallQual_9
# 6. PoolArea_555
# 7. RoofMatl_WdShngl
# 8. TotalBsmtSF
# 9. FullBath_3
# 10. Neighborhood_StoneBr
#
# Feature Drift:
# None

# %%
# score the model
rmse = mean_squared_error(
    y_true=testy.iloc[:,0].to_numpy(),
    y_pred=predictions,
    squared=False,
)
r2 = r2_score(
    y_true=testy.iloc[:,0].to_numpy(),
    y_pred=predictions,
)

print(f"RMSE: {rmse}")
print(f"R2: {r2}")
# Out:
# RMSE: 23499.204036992076
# R2: 0.8878847904438694

# %%
# save the machine learning pipeline
model.dump()

# %%
# refit the model to include the test data
model.refit(testX, testy)
# Out:
# Model Retraining:
# > Transforming The Updated Data
# > Extracting Time Features
# > Transforming Categorical Features
# > Removing Constant Features
# > Scaling Features
# > Training Lasso
# 2.95 Seconds
# Model Indicators:
# > Extracting Important Features
# 0.66 Seconds
